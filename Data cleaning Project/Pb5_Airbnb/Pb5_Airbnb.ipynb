# %% [markdown]
# # Data cleaning of Aitbnb dataset

# %% [markdown]
# ## Import data

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Data sets\Data cleaning Project\Pb5_Airbnb\Airbnb_Open_Data.csv", low_memory = False)

# %% [markdown]
# Due to having multiple data types at once neet to uplode at a same time given low memory = False
# The low_memory option is a boolean parameter that controls whether
# Pandas should read the CSV file in chunks or load the entire file into memory at once. By default, low_memory is set to True,
# which means Pandas will attempt to read the file in chunks to conserve memory.

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %% [markdown]
# ## Checking Data informaation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# ## delete the unwanted columns

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
column_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license', 'id' ]

# %%
len(column_to_drop)
# Out:
# 7

# %%
df = df.drop(columns = column_to_drop)

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.shape
# Out:
# (102599, 19)

# %% [markdown]
# ## Rename Columns

# %%
df.rename ( columns ={ "NAME" : "Name"}, inplace = True)

# %%
df
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
new_column_name = []
for i in df.columns:
    new_column_name.append(i.capitalize())

# %%
new_column_name
# Out:
# ['Name',
#  'Host id',
#  'Host_identity_verified',
#  'Host name',
#  'Neighbourhood group',
#  'Neighbourhood',
#  'Lat',
#  'Long',
#  'Country',
#  'Country code',
#  'Instant_bookable',
#  'Cancellation_policy',
#  'Room type',
#  'Construction year',
#  'Price',
#  'Service fee',
#  'Minimum nights',
#  'Number of reviews',
#  'Last review']

# %%
df.columns = new_column_name

# %%
df.columns
# Out:
# Index(['Name', 'Host id', 'Host_identity_verified', 'Host name',
#        'Neighbourhood group', 'Neighbourhood', 'Lat', 'Long', 'Country',
#        'Country code', 'Instant_bookable', 'Cancellation_policy', 'Room type',
#        'Construction year', 'Price', 'Service fee', 'Minimum nights',
#        'Number of reviews', 'Last review'],
#       dtype='object')

# %%
df
# Out:
#                                                     Name      Host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        Host_identity_verified    Host name Neighbourhood group  \
# ...

# %% [markdown]
# ## Droping duplicates

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 102594     True
# 102595     True
# 102596     True
# 102597     True
# 102598     True
# Length: 102599, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(541)

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102058 entries, 0 to 102057
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Name                    101808 non-null  object
#  1   Host id                 102058 non-null  int64
#  2   Host_identity_verified  101769 non-null  object
#  3   Host name               101654 non-null  object
#  4   Neighbourhood group     102029 non-null  object
#  5   Neighbourhood           102042 non-null  object
#  6   Lat                     102050 non-null  float64
#  7   Long                    102050 non-null  float64
#  8   Country                 101526 non-null  object
#  9   Country code            101927 non-null  object
#  10  Instant_bookable        101953 non-null  object
#  11  Cancellation_policy     101982 non-null  object
#  12  Room type               102058 non-null  object
#  13  Construction year       101844 non-null  float64
# ...

# %% [markdown]
# ## Remove NaN values

# %%
df.isna().sum()
# Out:
# Name                        250
# Host id                       0
# Host_identity_verified      289
# Host name                   404
# Neighbourhood group          29
# Neighbourhood                16
# Lat                           8
# Long                          8
# Country                     532
# Country code                131
# Instant_bookable            105
# Cancellation_policy          76
# Room type                     0
# Construction year           214
# Price                       247
# Service fee                 273
# Minimum nights              400
# Number of reviews           183
# Last review               15832
# dtype: int64

# %%
# drop last review column
df = df.drop(columns=['Last review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102058 entries, 0 to 102057
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Name                    101808 non-null  object
#  1   Host id                 102058 non-null  int64
#  2   Host_identity_verified  101769 non-null  object
#  3   Host name               101654 non-null  object
#  4   Neighbourhood group     102029 non-null  object
#  5   Neighbourhood           102042 non-null  object
#  6   Lat                     102050 non-null  float64
#  7   Long                    102050 non-null  float64
#  8   Country                 101526 non-null  object
#  9   Country code            101927 non-null  object
#  10  Instant_bookable        101953 non-null  object
#  11  Cancellation_policy     101982 non-null  object
#  12  Room type               102058 non-null  object
#  13  Construction year       101844 non-null  float64
# ...

# %%
# drop Nan
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Name                      0
# Host id                   0
# Host_identity_verified    0
# Host name                 0
# Neighbourhood group       0
# Neighbourhood             0
# Lat                       0
# Long                      0
# Country                   0
# Country code              0
# Instant_bookable          0
# Cancellation_policy       0
# Room type                 0
# Construction year         0
# Price                     0
# Service fee               0
# Minimum nights            0
# Number of reviews         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99342 entries, 0 to 102040
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    99342 non-null  object
#  1   Host id                 99342 non-null  int64
#  2   Host_identity_verified  99342 non-null  object
#  3   Host name               99342 non-null  object
#  4   Neighbourhood group     99342 non-null  object
#  5   Neighbourhood           99342 non-null  object
#  6   Lat                     99342 non-null  float64
#  7   Long                    99342 non-null  float64
#  8   Country                 99342 non-null  object
#  9   Country code            99342 non-null  object
#  10  Instant_bookable        99342 non-null  object
#  11  Cancellation_policy     99342 non-null  object
#  12  Room type               99342 non-null  object
#  13  Construction year       99342 non-null  float64
# ...

# %% [markdown]
# ## Cleaning colum indutially

# %%
df
# Out:
#                                                     Name      Host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        Host_identity_verified  Host name Neighbourhood group  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %% [markdown]
# chage case in Host_identity_verified

# %%
df["Host_identity_verified"] = df["Host_identity_verified"].str.upper()

# %%
df
# Out:
#                                                     Name      Host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        Host_identity_verified  Host name Neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# Chage Instant_bookable column boolean to numeric

# %%
df["Instant_bookable"].apply( lambda x:1 if x == True else 0 )
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: Instant_bookable, Length: 99342, dtype: int64

# %%
df["Instant_bookable"] = df["Instant_bookable"].apply( lambda x:1 if x == True else 0 )

# %%
df["Instant_bookable"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Change index series

# %%
df.index
# Out:
# Index([     0,      1,      4,      5,      7,      8,      9,     10,     11,
#            13,
#        ...
#        102024, 102025, 102026, 102027, 102028, 102029, 102030, 102031, 102032,
#        102040],
#       dtype='int64', length=99342)

# %%
# Reset index
df = df.reset_index()

# %%
df
# Out:
#         index                                              Name      Host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# drop old index column
df = df.drop(columns = "index")

# %%
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %% [markdown]
# # Column wise cleaning
# ## Change Price & Serice fee column into float
# ## to do that remove $ symbole

# %%
df["Price"] = df["Price"].str.replace("$","")

# %%
df["Price"] = df["Price"].str.replace(" ","")

# %%
df["Price"] = df["Price"].str.replace(",","")

# %%
df["Price"] = df["Price"].astype(int)

# %%
df["Service fee"] = df["Service fee"].str.replace("$","")

# %%
df["Service fee"].astype(int)
# Out:
# 0        193
# 1         28
# 2         41
# 3        115
# 4        212
#         ...
# 99337    164
# 99338     91
# 99339    216
# 99340     21
# 99341    196
# Name: Service fee, Length: 99342, dtype: int64

# %%
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99342 entries, 0 to 99341
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    99342 non-null  object
#  1   Host id                 99342 non-null  int64
#  2   Host_identity_verified  99342 non-null  object
#  3   Host name               99342 non-null  object
#  4   Neighbourhood group     99342 non-null  object
#  5   Neighbourhood           99342 non-null  object
#  6   Lat                     99342 non-null  float64
#  7   Long                    99342 non-null  float64
#  8   Country                 99342 non-null  object
#  9   Country code            99342 non-null  object
#  10  Instant_bookable        99342 non-null  int64
#  11  Cancellation_policy     99342 non-null  object
#  12  Room type               99342 non-null  object
#  13  Construction year       99342 non-null  float64
# ...

# %%
# Change type of Minimum nights column and number of review
df["Minimum nights"] = df["Minimum nights"].astype(int)

# %%
df["Number of reviews"] = df["Number of reviews"].astype(int)

# %%
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
df["Country code"].unique()
# Out:
# array(['US'], dtype=object)

# %%
df["Country"].unique()
# Out:
# array(['United States'], dtype=object)

# %%
# As seen the unquie  value of the column no need 2 of them  drop one 

df = df.drop(columns = "Country")

# %%
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# Chnge intial letter as caps in column Cancellation_policy
df["Cancellation_policy"] = df["Cancellation_policy"].str.capitalize()
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# Change type of Construction year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99342 entries, 0 to 99341
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    99342 non-null  object
#  1   Host id                 99342 non-null  int64
#  2   Host_identity_verified  99342 non-null  object
#  3   Host name               99342 non-null  object
#  4   Neighbourhood group     99342 non-null  object
#  5   Neighbourhood           99342 non-null  object
#  6   Lat                     99342 non-null  float64
#  7   Long                    99342 non-null  float64
#  8   Country code            99342 non-null  object
#  9   Instant_bookable        99342 non-null  int64
#  10  Cancellation_policy     99342 non-null  object
#  11  Room type               99342 non-null  object
#  12  Construction year       99342 non-null  float64
#  13  Price                   99342 non-null  int64
# ...

# %%
df["Construction year"] = df["Construction year"].astype(int)

# %%
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# combining Lat Long Column

df["Lat"] + df["Long"]
# Out:
# 0       -33.32488
# 1       -33.23015
# 2       -33.14548
# 3       -33.22733
# 4       -33.26908
#            ...
# 99337   -33.15692
# 99338   -33.22887
# 99339   -33.25840
# 99340   -33.00302
# 99341   -33.11693
# Length: 99342, dtype: float64

# %%
# its in float need to change in to string 
df["Lat"] = df["Lat"].astype(str)

# %%
df["Long"] = df["Long"].astype(str)

# %%
df["Lat"] = (df["Lat"] + df["Long"])

# %%
# Drop Long column
df = df.drop(columns = "Long")

# %%
# Rename Lat column into Long 

df = df.rename(columns = {"Lat" : "Lat_Long"})

# %%
df
# Out:
#                                                    Name      Host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       Host_identity_verified  Host name Neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
df["Room type"].value_counts()
# Out:
# Room type
# Entire home/apt    52054
# Private room       45022
# Shared room         2158
# Hotel room           108
# Name: count, dtype: int64

# %%
df.to_csv(r"D:\Data sets\Data cleaning Project\Pb5_Airbnb\Cleaned_Airbnb_Open_Data.csv")
