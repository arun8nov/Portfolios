# %%
# import pandas
import pandas as pd

# %%
# Import csv
df = pd.read_csv("Cricketdataset.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1   YBK Jaiswal (IND)  2023-2024   11    20   1  1217  214*  64.05   1698
# 2      HC Brook (ENG)  2022-2024   19    31   1  1875   317  62.50   2117
# 3      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 63    CL Walcott (WI)  1948-1960   44    74   7  3798   220  56.68      -
# 64    CL Walcott (WI)  1948-1960   44    74   7  3798   220  56.68      -
#
#        SR  100  50  0    4s  6s
# 0   58.60   29  13  7  626+   6
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
# rename multiple columns in a list 

df=df.rename(columns = {'Mat' : 'Matchs' , 'NO' : 'Not_Out' , 'HS' : 'Highest_Inns_Score' , 'BF' : 'Balls_Faced' , 'SR' : 'Batting_Strike'})

# %%
df.head()
# Out:
#               Player       Span  Matchs  Inns  Not_Out  Runs  \
# 0   DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1  YBK Jaiswal (IND)  2023-2024      11    20        1  1217
# 2     HC Brook (ENG)  2022-2024      19    31        1  1875
# 3     AC Voges (AUS)  2015-2016      20    31        7  1485
# 4    RG Pollock (SA)  1963-1970      23    41        4  2256
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50  0    4s  6s
# 0                334  99.94       9800+           58.60   29  13  7  626+   6
# 1               214*  64.05        1698           71.67    3   7  1   139  32
# 2                317  62.50        2117           88.56    6   9  1   210  29
# 3               269*  61.87        2667           55.68    5   4  2   186   5
# 4                274  60.97       1707+           54.48    7  11  1  246+  11

# %%
# Check Null Values 

df.isnull().any()
# Out:
# Player                False
# Span                  False
# Matchs                False
# Inns                  False
# Not_Out               False
# Runs                  False
# Highest_Inns_Score    False
# Ave                   False
# Balls_Faced            True
# Batting_Strike         True
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %%
df[df["Balls_Faced"].isna()==1]
# Out:
#                       Player       Span  Matchs  Inns  Not_Out  Runs  \
# 45  Inzamam-ul-Haq (ICC/PAK)  1992-2007     120   200       22  8830
# 47          FMM Worrell (WI)  1948-1963      51    87        9  3860
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50   0    4s  \
# 45                329  49.60         NaN           54.02   25  46  15  1105
# 47                261  49.48         NaN           40.16    9  22  11  240+
#
#     6s
# 45  48
# 47  11

# %%
df["Balls_Faced"]=df["Balls_Faced"].fillna(0)

# %%
df["Batting_Strike"]=df["Batting_Strike"].fillna(0)

# %%
df
# Out:
#                Player       Span  Matchs  Inns  Not_Out  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1   YBK Jaiswal (IND)  2023-2024      11    20        1  1217
# 2      HC Brook (ENG)  2022-2024      19    31        1  1875
# 3      AC Voges (AUS)  2015-2016      20    31        7  1485
# 4     RG Pollock (SA)  1963-1970      23    41        4  2256
# ..                ...        ...     ...   ...      ...   ...
# 60  WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 61    SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 62   DR Jardine (ENG)  1928-1934      22    33        6  1296
# 63    CL Walcott (WI)  1948-1960      44    74        7  3798
# 64    CL Walcott (WI)  1948-1960      44    74        7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50  0    4s  6s
# 0                 334  99.94       9800+           58.60   29  13  7  626+   6
# ...

# %%
df.isnull().any()
# Out:
# Player                False
# Span                  False
# Matchs                False
# Inns                  False
# Not_Out               False
# Runs                  False
# Highest_Inns_Score    False
# Ave                   False
# Balls_Faced           False
# Batting_Strike        False
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %%
# Cheking nas in specified columm by calling Player name
df[df["Player"]=="FMM Worrell (WI)"]
# Out:
#               Player       Span  Matchs  Inns  Not_Out  Runs  \
# 47  FMM Worrell (WI)  1948-1963      51    87        9  3860
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50   0    4s  \
# 47                261  49.48           0           40.16    9  22  11  240+
#
#     6s
# 47  11

# %%
# drop duplicates
# Check duplicated
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63     True
# 64     True
# Length: 65, dtype: bool

# %%
# getting duplicated rows 
df[df["Player"].duplicated()==1]
# Out:
#              Player       Span  Matchs  Inns  Not_Out  Runs  \
# 11  E Paynter (ENG)  1931-1939      20    31        5  1540
# 63  CL Walcott (WI)  1948-1960      44    74        7  3798
# 64  CL Walcott (WI)  1948-1960      44    74        7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50  0    4s  6s
# 11                243  59.23       1288+           45.88    4   7  3  125+   4
# 63                220  56.68           -            0.00   15  14  1  107+  11
# 64                220  56.68           -            0.00   15  14  1  107+  11

# %%
df[df["Player"].isin(['E Paynter (ENG)' , 'CL Walcott (WI)'])]
# Out:
#              Player       Span  Matchs  Inns  Not_Out  Runs  \
# 7   E Paynter (ENG)  1931-1939      20    31        5  1540
# 11  E Paynter (ENG)  1931-1939      20    31        5  1540
# 15  CL Walcott (WI)  1948-1960      44    74        7  3798
# 63  CL Walcott (WI)  1948-1960      44    74        7  3798
# 64  CL Walcott (WI)  1948-1960      44    74        7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50  0    4s  6s
# 7                 243  59.23       1288+           45.88    4   7  3  125+   4
# 11                243  59.23       1288+           45.88    4   7  3  125+   4
# 15                220  56.68           -            0.00   15  14  1  107+  11
# 63                220  56.68           -            0.00   15  14  1  107+  11
# 64                220  56.68           -            0.00   15  14  1  107+  11

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                Player       Span  Matchs  Inns  Not_Out  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1   YBK Jaiswal (IND)  2023-2024      11    20        1  1217
# 2      HC Brook (ENG)  2022-2024      19    31        1  1875
# 3      AC Voges (AUS)  2015-2016      20    31        7  1485
# 4     RG Pollock (SA)  1963-1970      23    41        4  2256
# ..                ...        ...     ...   ...      ...   ...
# 58   KD Walters (AUS)  1965-1981      74   125       14  5357
# 59  GC Smith (ICC/SA)  2002-2014     117   205       13  9265
# 60  WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 61    SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 62   DR Jardine (ENG)  1928-1934      22    33        6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50   0    4s  \
# 0                 334  99.94       9800+           58.60   29  13   7  626+
# ...

# %%
# Split up spam into Start and End Date

# %%
df["Span"].str.split("-")
# Out:
# 0     [1928, 1948]
# 1     [2023, 2024]
# 2     [2022, 2024]
# 3     [2015, 2016]
# 4     [1963, 1970]
#           ...
# 58    [1965, 1981]
# 59    [2002, 2014]
# 60    [1924, 1934]
# 61    [1930, 1938]
# 62    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df["Span"].str.split("-").str[0]
# Out:
# 0     1928
# 1     2023
# 2     2022
# 3     2015
# 4     1963
#       ...
# 58    1965
# 59    2002
# 60    1924
# 61    1930
# 62    1928
# Name: Span, Length: 62, dtype: object

# %%
df["Rookie_Year"]=df["Span"].str.split("-").str[0]
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_9356\3346374296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Rookie_Year"]=df["Span"].str.split("-").str[0]

# %%
df["Final_Year"]=df["Span"].str.split("-").str[1]
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_9356\401855648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Final_Year"]=df["Span"].str.split("-").str[1]

# %%
df
# Out:
#                Player       Span  Matchs  Inns  Not_Out  Runs  \
# 0    DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1   YBK Jaiswal (IND)  2023-2024      11    20        1  1217
# 2      HC Brook (ENG)  2022-2024      19    31        1  1875
# 3      AC Voges (AUS)  2015-2016      20    31        7  1485
# 4     RG Pollock (SA)  1963-1970      23    41        4  2256
# ..                ...        ...     ...   ...      ...   ...
# 58   KD Walters (AUS)  1965-1981      74   125       14  5357
# 59  GC Smith (ICC/SA)  2002-2014     117   205       13  9265
# 60  WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 61    SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 62   DR Jardine (ENG)  1928-1934      22    33        6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike  100  50   0    4s  \
# 0                 334  99.94       9800+           58.60   29  13   7  626+
# ...

# %%
df = df.drop(columns = "Span")

# %%
df
# Out:
#                Player  Matchs  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman (AUS)      52    80       10  6996                334  99.94
# 1   YBK Jaiswal (IND)      11    20        1  1217               214*  64.05
# 2      HC Brook (ENG)      19    31        1  1875                317  62.50
# 3      AC Voges (AUS)      20    31        7  1485               269*  61.87
# 4     RG Pollock (SA)      23    41        4  2256                274  60.97
# ..                ...     ...   ...      ...   ...                ...    ...
# 58   KD Walters (AUS)      74   125       14  5357                250  48.26
# 59  GC Smith (ICC/SA)     117   205       13  9265                277  48.25
# 60  WH Ponsford (AUS)      29    48        4  2122                266  48.22
# 61    SJ McCabe (AUS)      39    62        5  2748                232  48.21
# 62   DR Jardine (ENG)      22    33        6  1296                127  48.00
#
# ...

# %%
# Split Country from the Player

# %%
df["Player_Name"]=df["Player"].str.split("(").str[0]

# %%
df["Player_Country"]=df["Player"].str.split("(").str[1]

# %%
df
# Out:
#                Player  Matchs  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman (AUS)      52    80       10  6996                334  99.94
# 1   YBK Jaiswal (IND)      11    20        1  1217               214*  64.05
# 2      HC Brook (ENG)      19    31        1  1875                317  62.50
# 3      AC Voges (AUS)      20    31        7  1485               269*  61.87
# 4     RG Pollock (SA)      23    41        4  2256                274  60.97
# ..                ...     ...   ...      ...   ...                ...    ...
# 58   KD Walters (AUS)      74   125       14  5357                250  48.26
# 59  GC Smith (ICC/SA)     117   205       13  9265                277  48.25
# 60  WH Ponsford (AUS)      29    48        4  2122                266  48.22
# 61    SJ McCabe (AUS)      39    62        5  2748                232  48.21
# 62   DR Jardine (ENG)      22    33        6  1296                127  48.00
#
# ...

# %%
df["Player_Country"]=df["Player_Country"].str.replace(")","")

# %%
df
# Out:
#                Player  Matchs  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman (AUS)      52    80       10  6996                334  99.94
# 1   YBK Jaiswal (IND)      11    20        1  1217               214*  64.05
# 2      HC Brook (ENG)      19    31        1  1875                317  62.50
# 3      AC Voges (AUS)      20    31        7  1485               269*  61.87
# 4     RG Pollock (SA)      23    41        4  2256                274  60.97
# ..                ...     ...   ...      ...   ...                ...    ...
# 58   KD Walters (AUS)      74   125       14  5357                250  48.26
# 59  GC Smith (ICC/SA)     117   205       13  9265                277  48.25
# 60  WH Ponsford (AUS)      29    48        4  2122                266  48.22
# 61    SJ McCabe (AUS)      39    62        5  2748                232  48.21
# 62   DR Jardine (ENG)      22    33        6  1296                127  48.00
#
# ...

# %%
df["Player"]=df["Player_Name"]

# %%
df
# Out:
#           Player  Matchs  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80       10  6996                334  99.94
# 1   YBK Jaiswal       11    20        1  1217               214*  64.05
# 2      HC Brook       19    31        1  1875                317  62.50
# 3      AC Voges       20    31        7  1485               269*  61.87
# 4    RG Pollock       23    41        4  2256                274  60.97
# ..           ...     ...   ...      ...   ...                ...    ...
# 58   KD Walters       74   125       14  5357                250  48.26
# 59     GC Smith      117   205       13  9265                277  48.25
# 60  WH Ponsford       29    48        4  2122                266  48.22
# 61    SJ McCabe       39    62        5  2748                232  48.21
# 62   DR Jardine       22    33        6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike  100  50   0    4s  6s Rookie_Year Final_Year  \
# ...

# %%
df = df.drop(columns = "Player_Name")

# %%
df
# Out:
#           Player  Matchs  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80       10  6996                334  99.94
# 1   YBK Jaiswal       11    20        1  1217               214*  64.05
# 2      HC Brook       19    31        1  1875                317  62.50
# 3      AC Voges       20    31        7  1485               269*  61.87
# 4    RG Pollock       23    41        4  2256                274  60.97
# ..           ...     ...   ...      ...   ...                ...    ...
# 58   KD Walters       74   125       14  5357                250  48.26
# 59     GC Smith      117   205       13  9265                277  48.25
# 60  WH Ponsford       29    48        4  2122                266  48.22
# 61    SJ McCabe       39    62        5  2748                232  48.21
# 62   DR Jardine       22    33        6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike  100  50   0    4s  6s Rookie_Year Final_Year  \
# ...

# %%
# Change Data Type

# %%
df.dtypes
# Out:
# Player                 object
# Matchs                  int64
# Inns                    int64
# Not_Out                 int64
# Runs                    int64
# Highest_Inns_Score     object
# Ave                   float64
# Balls_Faced            object
# Batting_Strike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_Year            object
# Final_Year             object
# Player_Country         object
# dtype: object

# %%
df["Highest_Inns_Score"] = df["Highest_Inns_Score"].str.replace("*","")

# %%
df["Highest_Inns_Score"]=df["Highest_Inns_Score"].astype('int')

# %%
df.dtypes
# Out:
# Player                 object
# Matchs                  int64
# Inns                    int64
# Not_Out                 int64
# Runs                    int64
# Highest_Inns_Score      int32
# Ave                   float64
# Balls_Faced            object
# Batting_Strike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_Year            object
# Final_Year             object
# Player_Country         object
# dtype: object

# %%
# df["Rookie_Year"]=df["Rookie_Year"].astype('int')
# df["Final_Year"]=df["Final_Year"].astype('int')

# another way 
df = df.astype({"Rookie_Year" : "int" , "Final_Year" : "int" })

# %%
df.dtypes
# Out:
# Player                 object
# Matchs                  int64
# Inns                    int64
# Not_Out                 int64
# Runs                    int64
# Highest_Inns_Score      int32
# Ave                   float64
# Balls_Faced            object
# Batting_Strike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_Year             int32
# Final_Year              int32
# Player_Country         object
# dtype: object

# %%
df.head()
# Out:
#          Player  Matchs  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman       52    80       10  6996                 334  99.94
# 1  YBK Jaiswal       11    20        1  1217                 214  64.05
# 2     HC Brook       19    31        1  1875                 317  62.50
# 3     AC Voges       20    31        7  1485                 269  61.87
# 4   RG Pollock       23    41        4  2256                 274  60.97
#
#   Balls_Faced  Batting_Strike  100  50  0    4s  6s  Rookie_Year  Final_Year  \
# 0       9800+           58.60   29  13  7  626+   6         1928        1948
# 1        1698           71.67    3   7  1   139  32         2023        2024
# 2        2117           88.56    6   9  1   210  29         2022        2024
# 3        2667           55.68    5   4  2   186   5         2015        2016
# 4       1707+           54.48    7  11  1  246+  11         1963        1970
#
#   Player_Country
# 0            AUS
# 1            IND
# ...

# %%
df["Matchs"]
# Out:
# 0      52
# 1      11
# 2      19
# 3      20
# 4      23
#      ...
# 58     74
# 59    117
# 60     29
# 61     39
# 62     22
# Name: Matchs, Length: 62, dtype: int64

# %%
df.isnull().any()
# Out:
# Player                False
# Matchs                False
# Inns                  False
# Not_Out               False
# Runs                  False
# Highest_Inns_Score    False
# Ave                   False
# Balls_Faced           False
# Batting_Strike        False
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# Rookie_Year           False
# Final_Year            False
# Player_Country        False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                 object
# Matchs                  int64
# Inns                    int64
# Not_Out                 int64
# Runs                    int64
# Highest_Inns_Score      int32
# Ave                   float64
# Balls_Faced            object
# Batting_Strike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_Year             int32
# Final_Year              int32
# Player_Country         object
# dtype: object

# %%
# Find Career length and make as columm 
df["Career_length"]=df["Final_Year"]-df["Rookie_Year"]

# %%
df
# Out:
#           Player  Matchs  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80       10  6996                 334  99.94
# 1   YBK Jaiswal       11    20        1  1217                 214  64.05
# 2      HC Brook       19    31        1  1875                 317  62.50
# 3      AC Voges       20    31        7  1485                 269  61.87
# 4    RG Pollock       23    41        4  2256                 274  60.97
# ..           ...     ...   ...      ...   ...                 ...    ...
# 58   KD Walters       74   125       14  5357                 250  48.26
# 59     GC Smith      117   205       13  9265                 277  48.25
# 60  WH Ponsford       29    48        4  2122                 266  48.22
# 61    SJ McCabe       39    62        5  2748                 232  48.21
# 62   DR Jardine       22    33        6  1296                 127  48.00
#
#    Balls_Faced  Batting_Strike  100  50   0    4s  6s  Rookie_Year  \
# ...

# %%
df.dtypes
# Out:
# Player                 object
# Matchs                  int64
# Inns                    int64
# Not_Out                 int64
# Runs                    int64
# Highest_Inns_Score      int32
# Ave                   float64
# Balls_Faced            object
# Batting_Strike        float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Rookie_Year             int32
# Final_Year              int32
# Player_Country         object
# Career_length           int32
# dtype: object

# %%
# Calculas in df
# Averrage crickter's Career length 
df["Career_length"].mean()
# Out:
# 12.85483870967742

# %%
# Avg Batting_Strike for cricketers who played more than 10 yers 
df[df["Career_length"] > 10]["Batting_Strike"].mean()
# Out:
# 46.8493023255814

# %%
# Find number of cricketers played before 1960
df[df["Rookie_Year"] < 1960]["Player"].count()
# Out:
# 22

# %%
# Max Highest inns score by country
df.groupby("Player_Country")["Highest_Inns_Score"].max().to_frame("Highinncount").sort_values("Highinncount",ascending=False).reset_index()
# Out:
#    Player_Country  Highinncount
# 0          ICC/WI           400
# 1             AUS           380
# 2              SL           374
# 3             ENG           364
# 4         ICC/PAK           329
# 5         ICC/IND           319
# 6             PAK           313
# 7              WI           291
# 8              SA           278
# 9          ICC/SA           277
# 10            IND           254
# 11             NZ           251
# 12            ZIM           232
