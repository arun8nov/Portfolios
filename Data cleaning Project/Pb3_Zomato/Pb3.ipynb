# %% [markdown]
# # Zomato data cleaning
# # Data Cleaning:
#
# # Deleting redundant columns.
# # Renaming the columns.
# # Dropping duplicates.
# # Cleaning individual columns.
# # Remove the NaN values from the dataset
# # Check for some more Transformations

# %%
import pandas as pd

# %%
# Import data 
df = pd.read_csv(r"D:\Data sets\Data cleaning Project\Pb3\zomato.csv")

# %%
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
# see Column details 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
# see row,colums 
df.shape
# Out:
# (51717, 17)

# %%
# Deleting redundant columns
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
Columns_to_keep=['name', 'online_order', 'book_table', 'rate' , 'dish_liked', 'approx_cost(for two people)' ]
Columns_to_drop=['url', 'address','votes', 'phone', 'location', 'rest_type', 'cuisines', 'reviews_list', 'menu_item',
       'listed_in(type)', 'listed_in(city)']

# %%
len(Columns_to_keep)
# Out:
# 6

# %%
len(Columns_to_drop)
# Out:
# 11

# %%
# 1 method- Filtering Data

# %%
Columns_to_keep
# Out:
# ['name',
#  'online_order',
#  'book_table',
#  'rate',
#  'dish_liked',
#  'approx_cost(for two people)']

# %%
df[Columns_to_keep]
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
# 2nd way droping collumns 
Columns_to_drop
# Out:
# ['url',
#  'address',
#  'votes',
#  'phone',
#  'location',
#  'rest_type',
#  'cuisines',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
# saving dataset by another methode 
df.drop(columns = Columns_to_drop , inplace = True )

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# # Renaming the columns.

# %%
df.head(1)
# Out:
#     name online_order book_table   rate  \
# 0  Jalsa          Yes        Yes  4.1/5
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#   approx_cost(for two people)
# 0                         800

# %%
df=df.rename(columns = {"name" : "Name" , "book_table" : "Book_Table" , "dish_liked" : "Dish_liked" , "approx_cost(for two people)" : "Approx for 2 people"})

# %%
df
# Out:
#                                                     Name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_Table    rate                                         Dish_liked  \
# ...

# %% [markdown]
# # captilze the column name using for loop by calling columns

# %%
df.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in df.columns:
    print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Dish_liked
# Approx for 2 people

# %% [markdown]
# # To make list

# %%
new_columns=[] # empty list 

for i in df.columns:
    new_columns.append(i.capitalize())

# %%
new_columns
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rate',
#  'Dish_liked',
#  'Approx for 2 people']

# %%
# acending new column names

# %%
df.columns = new_columns

# %%
df
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Dropping duplicates.

# %%
df.duplicated().sum()
# Out:
# 32808

# %%
df.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
df.duplicated().head(20)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.duplicated().tail(20)
# Out:
# 51697     True
# 51698     True
# 51699     True
# 51700     True
# 51701     True
# 51702     True
# 51703     True
# 51704     True
# 51705     True
# 51706     True
# 51707     True
# 51708     True
# 51709     True
# 51710     True
# 51711     True
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# dtype: bool

# %%
df=df.drop_duplicates()  # removing duplicates

# %%
df.duplicated().sum()  # check is there any duplicates left
# Out:
# 0

# %% [markdown]
# # Remove the NaN values from the dataset

# %%
df
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51631                                      Just Parathas           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %%
df.isna().sum()
# Out:
# Name                       0
# Online_order               0
# Book_table                 0
# Rate                    2418
# Dish_liked             10587
# Approx for 2 people      140
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Name                   0
# Online_order           0
# Book_table             0
# Rate                   0
# Dish_liked             0
# Approx for 2 people    0
# dtype: int64

# %%
df
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %%
df=df.reset_index()

# %%
df
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table    Rate                                         Dish_liked  \
# ...

# %%
df = df.drop(columns="index")

# %%
df
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Cleaning individual columns.

# %%
df["Rate"]
# Out:
# 0        4.1/5
# 1        4.1/5
# 2        3.8/5
# 3        3.7/5
# 4        3.8/5
#          ...
# 8245    2.5 /5
# 8246    3.6 /5
# 8247    3.8 /5
# 8248    4.2 /5
# 8249    2.5 /5
# Name: Rate, Length: 8250, dtype: object

# %%
df["Rate"] = df["Rate"].str.replace(" " , "")

# %%
df["Rate"] = df["Rate"].str.replace("/" , " out of ")

# %%
df["Rate"]
# Out:
# 0       4.1 out of 5
# 1       4.1 out of 5
# 2       3.8 out of 5
# 3       3.7 out of 5
# 4       3.8 out of 5
#             ...
# 8245    2.5 out of 5
# 8246    3.6 out of 5
# 8247    3.8 out of 5
# 8248    4.2 out of 5
# 8249    2.5 out of 5
# Name: Rate, Length: 8250, dtype: object

# %%
df
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#               Rate                                         Dish_liked  \
# ...

# %% [markdown]
# # Check for some more Transformations

# %%
df["Online_order"]
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3        No
# 4        No
#        ...
# 8245     No
# 8246     No
# 8247    Yes
# 8248     No
# 8249     No
# Name: Online_order, Length: 8250, dtype: object

# %% [markdown]
# One methode
# df["Online_order"].str.replace("Yes","1")
# df["Online_order"].str.replace("No","0") and again we need to change data type

# %% [markdown]
# ### Using Lambda methode

# %%
df["Online_order"] = df["Online_order"].apply( lambda x:1 if x == "Yes" else 0)

# %%
df
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
df.to_csv(r"D:\Data sets\Data cleaning Project\Pb3\Final_zomato.csv")
