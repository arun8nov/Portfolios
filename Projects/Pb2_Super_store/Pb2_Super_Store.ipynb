# %% [markdown]
# # Import Libs and read data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns' , None)

# %%
df = pd.read_excel(r"D:\Data sets\Projects\Pb2_Super_store\P6-SuperStoreUS-2015.xlsx")

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %% [markdown]
# # Remove any null values in the field

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df =  df.fillna("")

# %%
df.isna().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# # Drop unwanted column and split data frame in to 3 Dfs to analyse data

# %%
df = df.drop(columns = 'Row ID')

# %%
df.columns
# Out:
# Index(['Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df_customer = df[['Customer ID','Customer Name','Customer Segment','Country', 'Region',
               'State or Province', 'City', 'Postal Code', 'Order ID']]

# %%
df_Product = df[['Order ID', 'Order Date', 'Order Priority','Product Category', 'Product Sub-Category', 
                 'Product Name','Quantity ordered new', 'Product Container','Ship Mode','Ship Date']]

# %%
df_sales = df[['Order ID','Order Date', 'Quantity ordered new', 'Unit Price', 'Sales', 'Discount','Shipping Cost', 'Profit','Product Base Margin']]

# %%
df_customer.info()
df_Product.info()
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        1952 non-null   int64
#  1   Customer Name      1952 non-null   object
#  2   Customer Segment   1952 non-null   object
#  3   Country            1952 non-null   object
#  4   Region             1952 non-null   object
#  5   State or Province  1952 non-null   object
#  6   City               1952 non-null   object
#  7   Postal Code        1952 non-null   int64
#  8   Order ID           1952 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 137.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order ID              1952 non-null   int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Order Priority        1952 non-null   object
#  1   Discount              1952 non-null   float64
#  2   Unit Price            1952 non-null   float64
#  3   Shipping Cost         1952 non-null   float64
#  4   Customer ID           1952 non-null   int64
#  5   Customer Name         1952 non-null   object
#  6   Ship Mode             1952 non-null   object
#  7   Customer Segment      1952 non-null   object
#  8   Product Category      1952 non-null   object
#  9   Product Sub-Category  1952 non-null   object
#  10  Product Container     1952 non-null   object
#  11  Product Name          1952 non-null   object
#  12  Product Base Margin   1952 non-null   object
#  13  Country               1952 non-null   object
#  14  Region                1952 non-null   object
# ...

# %%
df_sales
# Out:
#       Order ID Order Date  Quantity ordered new  Unit Price    Sales  \
# 0        88522 2015-01-07                     4        2.84    13.01
# 1        90193 2015-06-13                    12      500.98  6362.85
# 2        90192 2015-02-15                    22        9.48   211.15
# 3        86838 2015-05-12                    16       78.69  1164.45
# 4        86838 2015-05-12                     7        3.28    22.23
# ...        ...        ...                   ...         ...      ...
# 1947     87536 2015-03-11                    18       10.90   207.31
# 1948     87536 2015-03-11                    22        7.99   143.12
# 1949     87534 2015-03-29                     5       11.97    59.98
# 1950     87537 2015-04-04                    15        9.38   135.78
# 1951     87530 2015-02-08                     5      105.98   506.50
#
#       Discount  Shipping Cost     Profit Product Base Margin
# 0         0.01           0.93     4.5600                0.54
# ...

# %%
df_sales["Discount"] = (df_sales["Discount"]*100).astype(int)
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_15024\1816434049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sales["Discount"] = (df_sales["Discount"]*100).astype(int)

# %%
df_sales
# Out:
#       Order ID Order Date  Quantity ordered new  Unit Price    Sales  \
# 0        88522 2015-01-07                     4        2.84    13.01
# 1        90193 2015-06-13                    12      500.98  6362.85
# 2        90192 2015-02-15                    22        9.48   211.15
# 3        86838 2015-05-12                    16       78.69  1164.45
# 4        86838 2015-05-12                     7        3.28    22.23
# ...        ...        ...                   ...         ...      ...
# 1947     87536 2015-03-11                    18       10.90   207.31
# 1948     87536 2015-03-11                    22        7.99   143.12
# 1949     87534 2015-03-29                     5       11.97    59.98
# 1950     87537 2015-04-04                    15        9.38   135.78
# 1951     87530 2015-02-08                     5      105.98   506.50
#
#       Discount  Shipping Cost     Profit Product Base Margin
# 0            1           0.93     4.5600                0.54
# ...

# %%
df_sales = df_sales.rename(columns = {"Discount" : "Discount_%"})

# %%
df_sales
# Out:
#       Order ID Order Date  Quantity ordered new  Unit Price    Sales  \
# 0        88522 2015-01-07                     4        2.84    13.01
# 1        90193 2015-06-13                    12      500.98  6362.85
# 2        90192 2015-02-15                    22        9.48   211.15
# 3        86838 2015-05-12                    16       78.69  1164.45
# 4        86838 2015-05-12                     7        3.28    22.23
# ...        ...        ...                   ...         ...      ...
# 1947     87536 2015-03-11                    18       10.90   207.31
# 1948     87536 2015-03-11                    22        7.99   143.12
# 1949     87534 2015-03-29                     5       11.97    59.98
# 1950     87537 2015-04-04                    15        9.38   135.78
# 1951     87530 2015-02-08                     5      105.98   506.50
#
#       Discount_%  Shipping Cost     Profit Product Base Margin
# 0              1           0.93     4.5600                0.54
# ...

# %%
df_customer
# Out:
#       Customer ID      Customer Name Customer Segment        Country   Region  \
# 0               3      Bonnie Potter        Corporate  United States     West
# 1               5     Ronnie Proctor      Home Office  United States     West
# 2              11      Marcus Dunlap      Home Office  United States     East
# 3              14  Gwendolyn F Tyson   Small Business  United States  Central
# 4              14  Gwendolyn F Tyson   Small Business  United States  Central
# ...           ...                ...              ...            ...      ...
# 1947         3397        Andrea Shaw   Small Business  United States  Central
# 1948         3397        Andrea Shaw   Small Business  United States  Central
# 1949         3399        Marvin Reid   Small Business  United States  Central
# 1950         3400      Florence Gold   Small Business  United States     East
# 1951         3403      Tammy Buckley         Consumer  United States     West
#
# ...

# %%
df_Product
# Out:
#       Order ID Order Date Order Priority Product Category  \
# 0        88522 2015-01-07           High  Office Supplies
# 1        90193 2015-06-13  Not Specified        Furniture
# 2        90192 2015-02-15       Critical        Furniture
# 3        86838 2015-05-12         Medium        Furniture
# 4        86838 2015-05-12         Medium  Office Supplies
# ...        ...        ...            ...              ...
# 1947     87536 2015-03-11           High  Office Supplies
# 1948     87536 2015-03-11           High       Technology
# 1949     87534 2015-03-29  Not Specified  Office Supplies
# 1950     87537 2015-04-04         Medium        Furniture
# 1951     87530 2015-02-08           High        Furniture
#
#               Product Sub-Category  \
# 0              Pens & Art Supplies
# 1               Chairs & Chairmats
# 2               Office Furnishings
# 3               Office Furnishings
# 4              Pens & Art Supplies
# ...                            ...
# ...

# %%
len(df_Product["Product Category"].unique())
# Out:
# 3

# %%
len(df_Product["Product Sub-Category"].unique())
# Out:
# 17

# %%
len(df_Product["Product Name"].unique())
# Out:
# 913

# %%
len(df_Product["Product Container"].unique())
# Out:
# 7

# %%
len(df_Product["Ship Mode"].unique())
# Out:
# 3

# %%
len(df_Product["Order Priority"].unique())
# Out:
# 6

# %%
df_customer
# Out:
#       Customer ID      Customer Name Customer Segment        Country   Region  \
# 0               3      Bonnie Potter        Corporate  United States     West
# 1               5     Ronnie Proctor      Home Office  United States     West
# 2              11      Marcus Dunlap      Home Office  United States     East
# 3              14  Gwendolyn F Tyson   Small Business  United States  Central
# 4              14  Gwendolyn F Tyson   Small Business  United States  Central
# ...           ...                ...              ...            ...      ...
# 1947         3397        Andrea Shaw   Small Business  United States  Central
# 1948         3397        Andrea Shaw   Small Business  United States  Central
# 1949         3399        Marvin Reid   Small Business  United States  Central
# 1950         3400      Florence Gold   Small Business  United States     East
# 1951         3403      Tammy Buckley         Consumer  United States     West
#
# ...

# %%
len(df_customer["Customer Segment"].unique())
# Out:
# 4

# %%
df_customer.to_csv(r"D:\Data sets\Projects\Pb2_Super_store\P6-SuperStore_Customer.csv", index = False)

# %%
df_Product.to_csv(r"D:\Data sets\Projects\Pb2_Super_store\P6-SuperStore_Product.csv", index = False)

# %%
df_sales.to_csv(r"D:\Data sets\Projects\Pb2_Super_store\P6-SuperStore_Sales.csv", index = False)
