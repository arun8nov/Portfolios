# %% [markdown]
# # Scraping and Processing Rainfall Data for Climate Insights

# %% [markdown]
# ## Import Packages URL

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import datetime
from datetime import date

# %%
url = 'https://beta-tnsmart.rimes.int/index.php/Rainfall/daily_data'

# %%
response = requests.get(url)

# %%
# get html code gather the all data 
if response.status_code == 200:
    print("The HTML file was imported successfully.")
    soup = BeautifulSoup(response.text, 'html')
else:
    print("An error occurred while importing the file.")
    soup = []
# Out:
# The HTML file was imported successfully.

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="notranslate" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link href="https://beta-tnsmart.rimes.int/images/Homepage2.png" rel="icon" type="image/x-icon"/>
# <title>TN-SMART</title>
# <link href="https://beta-tnsmart.rimes.int/assets/css/main.css" rel="stylesheet"/>
# <!-- Tell the browser to be responsive to screen width -->
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <!-- Bootstrap 3.3.6 -->
# <link href="https://beta-tnsmart.rimes.int/assets/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://beta-tnsmart.rimes.int/assets/css/loading-btn.css" rel="stylesheet"/>
# <link href="https://beta-tnsmart.rimes.int/assets/css/loading.css" rel="stylesheet"/>
# <link href="https://beta-tnsmart.rimes.int/assets/bootstrap/css/bootstrap-multiselect.css" rel="stylesheet"/>
# <!-- Font Awesome -->
# <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.1/css/all.min.css" integrity="sha512-MV7K8+y+gLIBoVD59lQIYicR65iaqukzvf/nwasF0nqhPay5w/9lJmVM2hMDcnK1OnMGCdVK+iQrJ7lzPJQd1w==" referrerpolicy="no-referrer" rel="stylesheet"/>
# <!-- Ionicons -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/css/ionicons.min.css" rel="stylesheet"/>
# <!-- Theme style -->
# <link href="https://beta-tnsmart.rimes.int/assets/AdminLTE-2.3.11/dist/css/AdminLTE.min.css" rel="stylesheet"/>
# <!-- AdminLTE Skins. Choose a skin from the css/skins
#             folder instead of downloading all of them to reduce the load. -->
# <link href="https://beta-tnsmart.rimes.int/assets/AdminLTE-2.3.11/dist/css/skins/_all-skins.min.css" rel="stylesheet"/>
# <!-- datetimepicker -->
# <link href="https://beta-tnsmart.rimes.int/assets/bootstrap/css/jquery.datetimepicker.css" media="screen" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datetimepicker/4.17.47/css/bootstrap-datetimepicker.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.9.0/css/bootstrap-datepicker.css" rel="stylesheet" type="text/css"/>
# <link href="https://beta-tnsmart.rimes.int/assets/AdminLTE-2.3.11/plugins/daterangepicker/daterangepicker.css" rel="stylesheet"/>
# <link href="https://beta-tnsmart.rimes.int/assets/Fullscreen-Lightbox-Style-Gallery-Plugin-For-jQuery-jBox/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://beta-tnsmart.rimes.int/assets/Fullscreen-Lightbox-Style-Gallery-Plugin-For-jQuery-jBox/assets/scss/jBox.css" rel="stylesheet"/>
# <!-- colorbox -->
# <link href="https://beta-tnsmart.rimes.int/assets/bootstrap/css/colorbox.css" rel="stylesheet"/>
# <!-- flickity-docs -->
# <link href="https://beta-tnsmart.rimes.int/assets/flickity-docs/flickity.css" rel="stylesheet"/>
# <!-- about SMART carousel -->
# <link href="https://beta-tnsmart.rimes.int/assets/css/carousel.css" rel="stylesheet"/>
# <link href="//code.jquery.com/ui/1.11.4/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
# <!-- html2canvas / canvas2image -->
# <script src="https://beta-tnsmart.rimes.int/assets/html2canvas/html2canvas.js" type="text/javascript">
# </script>
# <script src="https://beta-tnsmart.rimes.int/assets/canvas2image/canvas2image.js" type="text/javascript">
# </script>
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDft-ArPjv12-0FSFY1_X2wPfLhDYnMkRQ&amp;v=3.exp&amp;libraries=weather,places,drawing"></script>
# <link href="https://unpkg.com/leaflet@1.6.0/dist/leaflet.css" rel="stylesheet"/>
# <script src="https://unpkg.com/leaflet@1.6.0/dist/leaflet.js"></script>
# <script src="https://unpkg.com/leaflet/dist/leaflet-src.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet-ajax/2.1.0/leaflet.ajax.min.js"></script>
# <!-- Google Captcha Script from Google refrences -->
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <script src="https://beta-tnsmart.rimes.int/geojson_file/pdf.js" type="text/javascript"></script>
# <script src="https://code.highcharts.com/maps/highmaps.js"></script>
# <script src="https://code.highcharts.com/maps/modules/exporting.js"></script>
# <script src="https://code.highcharts.com/maps/modules/offline-exporting.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>
# <script src="https://code.highcharts.com/modules/accessibility.js"></script>
# <!-- -->
# <!-- <script src="https://unpkg.com/geotiff@0.4.1/dist/main.js"></script>
#     <script src="https://unpkg.com/plotty@0.2.0/src/plotty.js"></script> -->
# <!-- -->
# <script src="https://unpkg.com/georaster"></script>
# <script src="https://unpkg.com/georaster-layer-for-leaflet/dist/georaster-layer-for-leaflet.min.js"></script>
# <!-- coordinates lat long on botton -->
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/leaflet-mouse-position@1.2.0/src/L.Control.MousePosition.min.css" rel="stylesheet"/>
# <script src="https://cdn.jsdelivr.net/npm/leaflet-mouse-position@1.2.0/src/L.Control.MousePosition.min.js"></script>
# <!-- -->
# <!-- pdf -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jspdf/2.5.1/jspdf.umd.min.js"></script>
# </head>
# <style type="text/css">
#     button.form-control{
#         background-color: #c5cdcf;
#     }
#     i{
#         color: black;
#     }
#     @media only screen and (min-width: 1441px) {
#         .wrapper {
#             height: 200px
#         }
#
#     }
#
#     .panel-default>.panel-heading {
#         background-color: #174a62;
#         color: white;
#     }
#
#     .panel-default {
#         margin: 0px;
#     }
#
#     .main-header {
#         /*
#                 height: 500px !important;
#                 float:left;*/
#         width: 100%;
#         height: auto !important;
#         margin-top: 0px;
#         /*position: relative;*/
#     }
#
#
#     .language,
#     .home {
#         background: none;
#         background-color: black;
#         /* Green */
#         border: none;
#         color: white;
#         padding: 5px;
#         text-align: center;
#         text-decoration: none;
#         margin: 2px;
#         cursor: pointer;
#         float: right;
#     }
#
#     .main-sidebar {
#         margin-top: 140px;
#         padding-top: 10px;
#     }
#
#     .navbar {
#         display: none;
#     }
#
#     @media screen and (min-width: 1025px) {
#         #bars {
#             display: none;
#         }
#
#         .main-footer {
#             margin-left: 120px;
#         }
#     }
#
#     @media screen and (max-width: 1024px) {
#         #bars {
#             display: block;
#         }
#
#
#
#     }
#
#     @media only screen and (max-width: 1024px) {
#         aside {
#             display: none;
#         }
#
#         .content-wrapper,
#         .main-footer {
#             margin-left: 0px;
#         }
#
#         .navbar {
#             min-height: 10px;
#             margin: 0px;
#             display: block;
#         }
#
#         .breadcrumb {
#             display: none;
#         }
#
#         #change_lan {
#             left: 85%;
#             display: block;
#         }
#     }
#
#     @media screen and (max-width: 700px) {
#         aside {
#             display: none;
#         }
#
#         .sidebar {
#             width: 100%;
#             height: auto;
#             position: relative;
#         }
#
#         .sidebar ul li a {
#             float: left;
#         }
#
#         div.content {
#             margin-left: 0;
#         }
#     }
#
#     @media screen and (max-width: 400px) {
#         aside {
#             display: none;
#         }
#
#         .sidebar ul li a {
#             text-align: center;
#             float: none;
#         }
#
#         #change_lang {
#             display: none;
#         }
#
#         #change_lan {
#             left: 65%;
#             display: block;
#         }
#     }
#
#     @media only screen and (max-width: 2560px) {
#         .main-header {
#             max-height: 250px;
#         }
#
#         .main-sidebar {
#             margin-top: 240px;
#         }
#     }
#
#     @media only screen and (max-width: 2200px) {
#         .main-header {
#             max-height: 250px;
#         }
#
#         .main-sidebar {
#             margin-top: 200px;
#         }
#     }
#
#     @media only screen and (max-width: 2000px) {
#         .main-header {
#             max-height: 250px;
#         }
#
#         .main-sidebar {
#             margin-top: 180px;
#         }
#     }
#
#     @media only screen and (max-width: 1600px) {
#         .main-header {
#             max-height: 250px;
#         }
#
#         .main-sidebar {
#             margin-top: 140px;
#         }
#     }
#
#     @media only screen and (max-width: 1336px) {
#         .main-header {
#             max-height: 150px;
#         }
#
#         .main-sidebar {
#             margin-top: 100px;
#         }
#     }
#
#     @media only screen and (max-width: 1024px) {
#         .main-header {
#             max-height: 100px;
#         }
#
#         .main-sidebar {
#             margin-top: 90px;
#         }
#     }
#
#     a {
#         color: #184a62;
#         font-weight: bold;
#     }
#
#     .btn-primary {
#         background-color: #184a62;
#     }
#
#     .box.box-solid.box-primary,
#     .box.box-primary {
#         border: 1px solid #fff;
#
#     }
#
#     .nav-tabs-custom>.nav-tabs>li.active {
#         border-top-color: #184a62;
#     }
#
#     .nav-tabs-custom>.nav-tabs>li>a {
#         color: #8e8e8e;
#     }
#
#     .content-wrapper {
#         margin-left: 120px;
#
#     }
#
#     .leaflet-control-velocity {
#         background-color: rgba(255, 255, 255, 0.7);
#         padding: 0 5px;
#         margin: 0 !important;
#         color: #333;
#         font: 11px/1.5 "Helvetica Neue", Arial, Helvetica, sans-serif;
#     }
#
#     .velocity-overlay {
#         position: absolute;
#         z-index: 1;
#     }
# </style>
# <body class="hold-transition skin-blue-light sidebar-mini sidebar-mini">
# <header class="main-header">
# <img src="https://beta-tnsmart.rimes.int/images/TNSMART_2.png" width="100%"/>
# </header>
# <nav class="nav" style="background-color: #f5f5f5;">
# <div id="change_lan">
# <a class="home btn-primary" href="https://beta-tnsmart.rimes.int/index.php/Home" id="home" style="float:left;background-color:#a6bad5"><i class="fa fa-lg ion-home"></i></a>
# <button aria-hidden="true" class="fa fa-x fa-bars" data-target="#modalForm" data-toggle="modal" id="bars" style="border: 0px;background-color: #184a62;color:white;float:left" type="button"></button>
# <a class="language btn-primary" href="https://beta-tnsmart.rimes.int/index.php/Publics/switchLanguage/tamil" style="float:right;background-color: #a6bad5; color:black">த</a>
# <a class="language btn-primary" href="https://beta-tnsmart.rimes.int/index.php/Publics/switchLanguage/english" style="float:right;background-color: #a6bad5; color:black">En</a>
# <a class="language btn-primary" href="JavaScript:if(confirm('Are you sure you want to logout?')==true) { window.location='https://beta-tnsmart.rimes.int/index.php/Login/logout'}" style="float:right;background-color: #a6bad5; color:black"><i class="fa fa-x fa-power-off"></i></a>
# </div>
# </nav>
# <!-- Left side column. contains the logo and sidebar -->
# <style>
#     @media only screen and (min-width:  1024px){
#         .main-sidebar{
#             width: 120px;
#         }
#
#     }
#     @media only screen and (max-width:  1024px){
#         .main-sidebar{
#             width: 0px;
#         }
#         .content-wrapper{
#             margin-left: 0px;
#         }
#     }
#     #tamil{
#         font-size: 12px;
#     }
#     #english{
#         font-size: 12px;
#
#     }
#     .side{
#         height: 20%;
#         text-align: center;
#         border-bottom: 1px solid #184a62;
#         padding-bottom: 10px;
#         padding-top: 10px;
#         padding-left: 3px;
#         padding-right: 3px;
#         font-weight: bold;
#     }
#     .side i{
#         color: #184a62;
#     }
#     .side.active i{
#         color: #dfdfdf;
#     }
#     .side.active{
#         background-color: #184a62;
#         color:#dfdfdf;
#     }
# </style>
# <aside class="main-sidebar" id="">
# <section class="sidebar">
# <div class="side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Home';">
# <i class="fa ion-home fa-2x"></i><br/><span>தகவல் பலகை</span>
# </div>
# <div class="side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Vulnerable/flood';">
# <i class="fa-solid fa-house-flood-water fa-2x"></i><br/><span>பாதிப்புக்குள்ளாகும் <br/>பகுதிகளின் விவரம் - வெள்ளம்</span>
# </div>
# <!-- <div class=" side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Vulnerable/landslide';">
#                     <i class="fa-solid fa-hill-rockslide fa-2x"></i><br><span>பாதிப்புக்குள்ளாகும் <br>பகுதிகளின் விவரம் - நிலச்சரிவு</span>
#                 </div> -->
# <!--  <div class=" side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Hourly_data/tnau_aws';">
#                     <i class="fa fa-cloud fa-2x"></i><br><span>AWS</span>
#                 </div>
#  -->
# <div class="active side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Rainfall/daily_data';">
# <i class="fa fa-cloud fa-2x"></i><br/><span>மழையின் அளவு</span>
# </div>
# <div class="side" onclick="location.href=
#                 'https://beta-tnsmart.rimes.int/index.php/Reservoir/daily_data';">
# <i class="fa-solid fa-bridge-water fa-2x"></i><br/><span>நீர்தேக்கங்களின் அளவு</span>
# </div>
# <div class="side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Tanks/season_data';">
# <i class="fa-solid fa-glass-water fa-2x"></i><br/><span>Tanks</span>
# </div>
# <!-- <div class=" side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Dashboard/MIS/shelters';">
#                     <i class="fa-solid fa-database fa-2x"></i><br><span>MIS</span>
#                 </div> -->
# </section>
# </aside>
# <div class="modal fade" id="modalForm" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body" style="padding-left:10px; padding-right: 10px;">
# <p class="statusMsg"></p>
# <div class="side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Home';">
# <i class="fa ion-home fa-2x"></i><br/><span>தகவல் பலகை</span>
# </div>
# <div class="side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Vulnerable/flood';">
# <i class="fa-solid fa-house-flood-water fa-2x"></i><br/><span>பாதிப்புக்குள்ளாகும் <br/>பகுதிகளின் விவரம் - வெள்ளம்</span>
# </div>
# <!--  <div class=" side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Vulnerable/landslide';">
#                     <i class="fa-solid fa-hill-rockslide fa-2x"></i><br><span>பாதிப்புக்குள்ளாகும் <br>பகுதிகளின் விவரம் - நிலச்சரிவு</span>
#                 </div> -->
# <div class="active side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Rainfall/daily_data';">
# <i class="fa fa-cloud fa-2x"></i><br/><span>மழையின் அளவு</span>
# </div>
# <div class="side" onclick="window.location.href(
#                 'https://beta-tnsmart.rimes.int/index.php/Reservoir/daily_data';">
# <i class="fa-solid fa-water fa-2x"></i><br/><span>நீர்தேக்கங்களின் அளவு</span>
# </div>
# <div class="side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Tanks/season_data';">
# <i class="fa fa-tank-water fa-2x"></i><br/><span>tanks</span>
# </div>
# <!-- <div class=" side" onclick="location.href='https://beta-tnsmart.rimes.int/index.php/Dashboard/MIS/shelters';">
#                     <i class="fa-solid fa-database fa-2x"></i><br><span>MIS</span>
#                 </div> -->
# </div>
# </div>
# </div>
# </div>
# <!-- sidebar_database -->
# <!-- sidebar_public -->
# <style type="text/css">
# #data_table {
#     border: 1px solid black;
#     width: 100%;
#     overflow: auto;
#     height: 800px;
# }
#
# #table,
# #table td,
# #table th {
#     border: 1px solid black;
# }
#
# #popup_table tr th {
#     border: 1px solid black;
#     width: 20%;
#     text-align: center;
#     background-color: #f5f5f5;
#     color: black;
#     padding: 2px;
# }
#
# #popup_table tr td {
#     border: 1px solid black;
#     width: 20%;
#     text-align: center;
#     background-color: white;
#     color: black;
#     padding: 2px;
#
# }
#
# #data_table tr th {
#     border: 1px solid black;
#     width: 20%;
#     text-align: center;
#     background-color: white;
#     color: black;
#     padding: 10px;
# }
#
# #data_table tr td {
#     border: 1px solid black;
#     width: 20%;
#     text-align: center;
#     background-color: white;
#     color: black;
#     padding: 6px;
#
# }
#
# button,
# #submit {
#     background: none;
#     background-color: #8E8E8E;
#     /* Green */
#     border: none;
#     color: white;
#     padding: 10px 20px;
#     text-align: center;
#     text-decoration: none;
#     margin: 4px 2px;
#     cursor: pointer;
# }
#
# button:hover,
# .selected {
#     color: black;
# }
#
# .tamil {
#     font-size: 14px;
#     font-weight: normal;
# }
#
# label {
#     font-weight: normal;
# }
#
# .tamil {
#     font-size: 14px;
#     font-weight: normal;
# }
#
# @media only screen and (max-width: 1200px) {
#     .col-lg-6 {
#         padding: 0px;
#         width: 100%;
#     }
#
#     .content {
#         min-height: 2500px;
#     }
#
#     #label {
#         font-size: 20px;
#     }
# }
#
# @media only screen and (max-width: 768px) {
#     .col-lg-6 {
#         padding: 0px;
#         width: 100%;
#     }
#
#     .content {
#         min-height: 2500px;
#     }
#
#     #label {
#         font-size: 18px;
#     }
# }
#
# .panel {
#     margin-bottom: 0px;
# }
#
# @media only screen and (max-width: 500px) {
#     .col-lg-6 {
#         padding: 0px;
#         width: 100%;
#     }
#
#     .content {
#         min-height: 2500px;
#     }
#
#     .content-wrapper,
#     .main-footer {
#         margin-left: 0px;
#     }
#
#     #label {
#         font-size: 14px;
#     }
#
#     th {
#         font-size: 12px;
#     }
#
#     td {
#         font-size: 12px;
#     }
# }
#
# @media only screen and (min-width: 1200px) {
#     .col-lg-6 {
#         padding: 0px;
#         margin-right: 10px;
#
#         width: 49%;
#     }
#
#     .content {
#         min-height: 1600px;
#     }
#
#     #label {
#         font-size: 20px;
#     }
# }
#
# .dot {
#     height: 15px;
#     width: 15px;
#     border-radius: 50%;
#     display: inline-block;
#     border: 1px solid #000;
# }
#
# .legend_label {
#     padding: 5px;
# }
# </style>
# <div class="content-wrapper">
# <section class="content-header">
# <label style="font-weight: bold;font-size: 16px;">மழையின் அளவு</label>
# <ol class="breadcrumb">
# <li><i class="fa ion-home"></i> மழையின் அளவு</li>
# </ol>
# </section>
# <section class="content">
# <div class="box box-body">
# <ul class="nav nav-tabs">
# <li class="active"><a href="https://beta-tnsmart.rimes.int/index.php/Rainfall/daily_data">மாநிலம்</a></li>
# <li class=""><a href="https://beta-tnsmart.rimes.int/index.php/Rainfall/gcc_day">சென்னை</a></li>
# <li class=""><a href="https://beta-tnsmart.rimes.int/index.php/MIS/Rainfall/raingauge_stations/"> Station wise abstract </a></li>
# </ul>
# <div class="row">
# <form accept-charset="utf-8" action="https://beta-tnsmart.rimes.int/index.php/Rainfall/daily_data" enctype="multipart/form-data" method="post" role="form">
# <br/>
# <div class="col-lg-2 col-sm-12 col-md-3 col-xs-12">
# <label>Type</label>
# <select class="form-control" id="type" name="type" required="">
# <option value="">--Select--</option>
# <option value="1">District wise</option>
# <option value="2">Rainfall wise</option>
# </select>
# </div>
# <div class="col-lg-2 col-sm-12 col-md-3 col-xs-12">
# <label>தேதி</label><br/>
# <input id="date" name="date" required="" type="date"/>
# </div>
# <div class="col-lg-2 col-sm-12 col-md-9 col-xs-12">
# <label style="float: left">
# <input id="submit" name="submit" type="submit" value="சமர்ப்பிக்கவும்"/>
# </label>
# <label style="float: right;">
# <button onclick="printDiv('data_table')">
# <i aria-hidden="true" class="fa fa-print"></i>
# </button>
# </label>
# </div>
# </form> </div>
# </div>
# <!-- <div class="col-lg-12 box box-primary box-solid" >
#                 <label>** மழைமானி வாரியாக தகவல்களைப் பார்க்க மாவட்டத்தைத் தேர்ந்தெடுக்கவும்</label>
#                 <div id="container"></div>
#             </div> -->
# <div class="col-lg-6 box box-primary box-solid">
# <div class="panel panel-default">
# <div class="panel-heading" style="background-color: #f5f5f5;color:black">District wise observed Rainfall
#                     data on 30-Dec-2024</div>
# <div align="center" id="daily_district_map" style="width:100%;height: 600px;"></div>
# <div class="panel-footer" style="padding:0px">
# <table>
# <tfoot>
# <tr align="center">
# <td colspan="4">
# <label class="legend_label"><span class="dot" style="background-color: #ffffff;"></span> மழையின்மை</label>
# <label class="legend_label"><span class="dot" style="background-color: #bfbfbf;"></span>மிக லேசான மழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #DAF7A6;"></span>லேசான மழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #46C646;"></span>மிதமான மழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #FFFF00;"></span>கனமழை </label>
# <label class="legend_label"><span class="dot" style="background-color: #FFA500;"></span>மிக கனமழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #FF0000;"></span>அதி கனமழை</label>
# </td>
# </tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# <div class="col-lg-6 box box-primary box-solid">
# <div class="panel panel-default">
# <div class="panel-heading" style="background-color: #f5f5f5;color:black">Station wise observed Rainfall
#                     data on 30-Dec-2024</div>
# <div align="center" class="map_canvas" id="map" style="width:100%;height: 600px;"></div>
# <div class="panel-footer" style="padding:0px">
# <table>
# <tfoot>
# <tr align="center">
# <td colspan="4">
# <label class="legend_label"><span class="dot" style="background-color: #ffffff;"></span> மழையின்மை</label>
# <label class="legend_label"><span class="dot" style="background-color: #bfbfbf;"></span>மிக லேசான மழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #DAF7A6;"></span>லேசான மழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #46C646;"></span>மிதமான மழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #FFFF00;"></span>கனமழை </label>
# <label class="legend_label"><span class="dot" style="background-color: #FFA500;"></span>மிக கனமழை</label>
# <label class="legend_label"><span class="dot" style="background-color: #FF0000;"></span>அதி கனமழை</label>
# </td>
# </tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# <div class="col-lg-12 box box-primary box-solid" style="height: 720px;overflow-y: scroll;">
# <table id="data_table">
# <thead>
# <tr>
# <th>வரிசை எண்</th>
# <th>உரிமையாளர்</th>
# <th>மாவட்டம்</th>
# <th>மழைமானி நிலையம்</th>
# <th>பதிவான மழை அளவு (மி.மீ.)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Suthamalli dam</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Kuruvadi</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Jayankondam taluk office</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>PWD Office, Sendurai</th>
# <td class="color_code">
#                             3.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Taluk Office, Andimadam</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Ariyalur Taluk Office</th>
# <td class="color_code">
#                             2.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>THIRUMANUR  PWD OFFICE (R.C.DIVISION)</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>T.Palur Panchayat Union 0ffice</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>25.1</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>3.14</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Taluk Office, Thirukalukundram</th>
# <td class="color_code">
#                             45</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Mammallapuram PWD bungalow</th>
# <td class="color_code">
#                             38</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Keelampakkam</th>
# <td class="color_code">
#                             14.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Taluk Office, Thiruporur</th>
# <td class="color_code">
#                             10</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Chengalpattu</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Madurantakam taluk office</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Taluk Office, Tambaram</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>CMWSSB</th>
# <th class="district_color">Chengalpattu</th>
# <th>Alandur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>120.2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>13.36</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 15 Uthandi</th>
# <td class="color_code">
#                             15.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 15 Sholinganallur</th>
# <td class="color_code">
#                             5.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 12 Meenambakkam</th>
# <td class="color_code">
#                             3.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 12 Alandhur</th>
# <td class="color_code">
#                             3.3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Chennai</th>
# <th>Sholinganallur</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 09 Ice House</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Chennai</th>
# <th>Alandur</th>
# <td class="color_code">
#                             2.9</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 13 Raja Annamalai puram</th>
# <td class="color_code">
#                             2.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 14 Perungudi</th>
# <td class="color_code">
#                             2.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>CMWSSB</th>
# <th class="district_color">Chennai</th>
# <th>Sholinganallur</th>
# <td class="color_code">
#                             2.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Chennai</th>
# <th>Anna university</th>
# <td class="color_code">
#                             1.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 13 Adyar</th>
# <td class="color_code">
#                             1.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 14 Madipakkam</th>
# <td class="color_code">
#                             1.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 13 Velachery</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>CMWSSB</th>
# <th class="district_color">Chennai</th>
# <th>Perungudi</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>CMWSSB</th>
# <th class="district_color">Chennai</th>
# <th>Adyar</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>51.7</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.94</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Vanamadevi</th>
# <td class="color_code">
#                             15.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Panruti</th>
# <td class="color_code">
#                             15</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Pelandurai</th>
# <td class="color_code">
#                             13.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kurinjipadi</th>
# <td class="color_code">
#                             10</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>SRC Kudithangi</th>
# <td class="color_code">
#                             9</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Srimushnam</th>
# <td class="color_code">
#                             8.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Veppur</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Vadakuthu</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Vridhachalam</th>
# <td class="color_code">
#                             7</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Tozhudur</th>
# <td class="color_code">
#                             6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Indian Metrology Department</th>
# <td class="color_code">
#                             5.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kattumayilur</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kuppanatham</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Collectorate</th>
# <td class="color_code">
#                             4.9</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kilacheruvai</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Sethiyathope</th>
# <td class="color_code">
#                             3.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>17</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Me.Mathur</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>18</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kothavacherry</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>19</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Lalpet</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>20</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Annamalai Nagar</th>
# <td class="color_code">
#                             1.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>21</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kattumannarkoil</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>22</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Parangipettai</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>23</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Chidambaram</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>140.2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>5.61</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>Palani</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>Kamatchipuram</th>
# <td class="color_code">
#                             0.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>VEDASANDUR</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>TOBACCO STATION(VDR)</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>3</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Kancheepuram</th>
# <th>Sriperumbadur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Kancheepuram</th>
# <th>Kancheepuram taluk office</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>3</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Madurai</th>
# <th>Elumalai</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>0.4</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.02</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Mayiladuthurai</th>
# <th>Mayiladuthurai</th>
# <td class="color_code">
#                             4.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Mayiladuthurai</th>
# <th>Sirkali</th>
# <td class="color_code">
#                             2.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Mayiladuthurai</th>
# <th>Sembanarkoil (PWD)</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>8.2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>1.37</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Nagapattinam</th>
# <td class="color_code">
#                             81.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Velankanni</th>
# <td class="color_code">
#                             72.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Thirupoondi</th>
# <td class="color_code">
#                             13.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Kodiayakarai</th>
# <td class="color_code">
#                             10.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Vedaranyam</th>
# <td class="color_code">
#                             9.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Thirukuvalai</th>
# <td class="color_code">
#                             7</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Thalanayar</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>198.5</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>28.36</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Puthu vettakudi</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Labbaikudikadu</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Agaram seegoor</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Eraiyur</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>VEPPANTHATTAI</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>V.KALATHUR</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Chettikulam</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Perambalur</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>23</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>2.09</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Gandarvakottai</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Karaiyur</th>
# <td class="color_code">
#                             5.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Perungalur</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Malaiyur</th>
# <td class="color_code">
#                             4.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Alangudi</th>
# <td class="color_code">
#                             4.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Pudukkottai</th>
# <td class="color_code">
#                             4.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Karambakudi</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Kudimiyanmalai</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>THIRUMAYAM</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Manamelkudi</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Annavasal</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Keeranur</th>
# <td class="color_code">
#                             1.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>47.5</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>1.98</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>Mandapam</th>
# <td class="color_code">
#                             1.1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>pamban</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>Thangachimadam</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>Rameswaram</th>
# <td class="color_code">
#                             0.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>3.9</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.24</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Salem</th>
# <th>Yercaud</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>1</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.06</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Sivagangai</th>
# <th>Thiruppathur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.22</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Orathanad</th>
# <td class="color_code">
#                             25</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Neivasal Thenpathi</th>
# <td class="color_code">
#                             20</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Vettikadu</th>
# <td class="color_code">
#                             19.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Madukkur</th>
# <td class="color_code">
#                             15.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Kurungulam</th>
# <td class="color_code">
#                             11</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Vallam</th>
# <td class="color_code">
#                             7</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thirukkattupalli</th>
# <td class="color_code">
#                             3.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Ayyampettai</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thiruvidaimaruthur</th>
# <td class="color_code">
#                             2.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Papanasam</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Manjalaru</th>
# <td class="color_code">
#                             1.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Lower Anaicut</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Echanviduthi</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Taluk Office, Kumbakonam</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thiruvaiyaru</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Pattukkottai</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>17</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Grand Anaicut</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>18</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thanjavur</th>
# <td class="color_code">
#                             0.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>19</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Adirampatnam</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>117.7</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>5.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Thenparanadu</th>
# <td class="color_code">
#                             14</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Tiruchirappalli Town</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Thuvakudi</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Tiruchirappalli Junction</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Tiruchirappalli Airport</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>19</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.79</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Needamangalam</th>
# <td class="color_code">
#                             35.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Mannargudi</th>
# <td class="color_code">
#                             32</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Taluk Office , Tiruvarur</th>
# <td class="color_code">
#                             31</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Kudavasal</th>
# <td class="color_code">
#                             19.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Taluk Office, Nannilam</th>
# <td class="color_code">
#                             14.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Pandavaiyaru</th>
# <td class="color_code">
#                             12.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# ...
# map_chart('daily_district_map', "Rainfall in mm", district_map, '#AFEEEE');
#
# function map_chart(id, name, map_data, color) {
#     $.getJSON('https://beta-tnsmart.rimes.int/DATA/Map/district.geojson', function(geojson) {
#         Highcharts.mapChart(id, {
#             chart: {
#                 map: geojson,
#                 height: 600
#             },
#             title: {
#                 text: ''
#             },
#             legend: {
#                 enabled: false
#             },
#             exporting: {
#                 enabled: false
#             },
#             colorAxis: {
#                 dataClasses: [{
#                     from: 0,
#                     to: 0.09,
#                     color: '#fff',
#                     name: 'No rain'
#                 }, {
#                     from: 0.1,
#                     to: 2.4,
#                     color: '#bfbfbf',
#                     name: 'Very light'
#                 }, {
#                     from: 2.41,
#                     to: 15.6,
#                     color: '#daf7a6',
#                     name: '0.01 to 7.6 mm'
#                 }, {
#                     from: 15.61,
#                     to: 64.4,
#                     color: '#46c646',
#                     name: '7.61 to 64.4 mm'
#                 }, {
#                     from: 64.41,
#                     to: 115.5,
#                     color: '#ffff00',
#                     name: '64.41 to 115.5 mm'
#                 }, {
#                     from: 115.51,
#                     to: 204.4,
#                     color: '#ffa500',
#                     name: '115.51 to 204.4 mm'
#                 }, {
#                     from: 204.41,
#                     color: '#ff0000',
#                     name: 'Above 204.41 mm'
#                 }]
#             },
#             mapNavigation: {
#                 enabled: false,
#                 buttonOptions: {
#                     verticalAlign: 'bottom'
#                 }
#             },
#
#             series: [{
#                 data: map_data,
#                 keys: ['dist_name', 'value'],
#                 joinBy: 'dist_name',
#                 name: name,
#                 states: {
#                     hover: {
#                         color: color
#                     }
#                 },
#                 dataLabels: {
#                     enabled: true,
#                     format: '{point.properties.dist_name}'
#                 },
#
#             }]
#         });
#     });
# }
#
# /*Highcharts.chart('container', {
#     chart: {
#         type: 'column',scrollablePlotArea: {minWidth: 1400,
#             scrollPositionX: 1
#         }
#     },
#     title: {
#         text: 'தினசரி சராசரி மழை (மி.மீ) - 30-Dec-2024'
#     },
#
#     accessibility: {
#         announceNewData: {
#             enabled: true
#         }
#     },
#     xAxis: {
#         type: 'category'
#     },
#     yAxis: {
#         title: {
#             text: 'Average Rainfall in mm'
#         }
#
#     },
#     legend: {
#         enabled: false
#     },
#     plotOptions: {
#         series: {
#             borderWidth: 0,
#             dataLabels: {
#                 enabled: true,
#                 format: '{point.y:.1f}'
#             }
#         }
#     },
#
#     tooltip: {
#         headerFormat: '<span style="font-size:11px">{series.name}</span><br>',
#         pointFormat: '<span style="color:{point.color}">{point.name}</span>: <b>{point.y:.2f} mm</b><br/>'
#     },
#
#     series: [
#         {
#             name: "District",
#             colorByPoint: true,
#             data:[
#             {name:"Ariyalur",y:3.14,color: "#DAF7A6",drilldown:"Ariyalur"},{name:"Chengalpattu",y:13.36,color: "#46C646",drilldown:"Chengalpattu"},{name:"Chennai",y:0.94,color: "#DAF7A6",drilldown:"Chennai"},{name:"Cuddalore",y:5.61,color: "#DAF7A6",drilldown:"Cuddalore"},{name:"Dindigul",y:0.30,color: "#DAF7A6",drilldown:"Dindigul"},{name:"Kancheepuram",y:0.50,color: "#DAF7A6",drilldown:"Kancheepuram"},{name:"Madurai",y:0.02,color: "#bfbfbf",drilldown:"Madurai"},{name:"Mayiladuthurai",y:1.37,color: "#DAF7A6",drilldown:"Mayiladuthurai"},{name:"Nagapattinam",y:28.36,color: "#46C646",drilldown:"Nagapattinam"},{name:"Perambalur",y:2.09,color: "#DAF7A6",drilldown:"Perambalur"},{name:"Pudukkottai",y:1.98,color: "#DAF7A6",drilldown:"Pudukkottai"},{name:"Ramanathapuram",y:0.24,color: "#DAF7A6",drilldown:"Ramanathapuram"},{name:"Salem",y:0.06,color: "#bfbfbf",drilldown:"Salem"},{name:"Sivagangai",y:0.22,color: "#DAF7A6",drilldown:"Sivagangai"},{name:"Thanjavur",y:5.60,color: "#DAF7A6",drilldown:"Thanjavur"},{name:"Thiruchirappalli",y:0.79,color: "#DAF7A6",drilldown:"Thiruchirappalli"},{name:"Thiruvarur",y:17.56,color: "#46C646",drilldown:"Thiruvarur"},{name:"Tirunelveli",y:6.27,color: "#DAF7A6",drilldown:"Tirunelveli"},{name:"Tiruppur",y:0.10,color: "#DAF7A6",drilldown:"Tiruppur"},{name:"Tiruvannamalai",y:0.58,color: "#DAF7A6",drilldown:"Tiruvannamalai"},{name:"Villupuram",y:3.02,color: "#DAF7A6",drilldown:"Villupuram"},            ]
#
#         }
#     ],
#     drilldown: {
#         series: [
#         {name:"Ariyalur",id:"Ariyalur",data:[["Suthamalli dam",5],["Kuruvadi",4],["Jayankondam taluk office",4],["PWD Office, Sendurai",3.6],["Taluk Office, Andimadam",3],["Ariyalur Taluk Office",2.5],["THIRUMANUR  PWD OFFICE (R.C.DIVISION)",2],["T.Palur Panchayat Union 0ffice",1],]},{name:"Chengalpattu",id:"Chengalpattu",data:[["Taluk Office, Thirukalukundram",45],["Mammallapuram PWD bungalow",38],["Keelampakkam",14.2],["Taluk Office, Thiruporur",10],["Chengalpattu",5],["Madurantakam taluk office",4],["Taluk Office, Tambaram",2],["Alandur",2],["Cheyyur",0],]},{name:"Chennai",id:"Chennai",data:[["Zone 15 Uthandi",15.6],["Zone 15 Sholinganallur",5.6],["Zone 12 Meenambakkam",3.6],["Zone 12 Alandhur",3.3],["Sholinganallur",3],["Zone 09 Ice House",3],["Alandur",2.9],["Zone 13 Raja Annamalai puram",2.4],["Zone 14 Perungudi",2.4],["Sholinganallur",2.2],["Anna university",1.8],["Zone 13 Adyar",1.8],["Zone 14 Madipakkam",1.5],["Zone 13 Velachery",1.2],["Perungudi",1],["Adyar",0.4],["Ayanavaram taluk office",0],["CD Hospital Tondiarpet",0],["Chennai collectorate building",0],["Chennai nungambakkam",0],["DGP Office",0],["Gov hr sec school MGR Nagar",0],["Perambur Corporation park",0],["Ambathur",0],["Thiruvottiyur",0],["Manali",0],["Madhavaram",0],["Tondairpet",0],["Royapuram",0],["Thiru-Vi-Ka Nagar",0],["Ambattur",0],["Anna Nagar",0],["Kodambakkam",0],["Valasaravakkam",0],["Puzhal",0],["Zone 01 Kathivakkam",0],["Zone 01 Thiruvottiyur",0],["Zone 02 Manali New town ",0],["Zone 02 Manali",0],["Zone 03 Madhavaram",0],["Zone 03 Puzhal",0],["Zone 04 Tondiarpet",0],["Zone 05 Chennai central",0],["Zone 05 Basin bridge",0],["Zone 06 Kolathur",0],["Zone 06 Perambur",0],["Zone 07 Ayapakkam",0],["Zone 07 Ambattur",0],["Zone 08 Aminjikarai",0],["Zone 08 Anna Nagar West",0],["Zone 09 Nungambakkam",0],["Zone 10 Vadapalani",0],["Zone 11 Maduravoyal",0],["Zone 11 Valasaravakkam",0],["Zone 12 Mugalivakkam",0],]},{name:"Coimbatore",id:"Coimbatore",data:[["Taluk Office, Anaimalai",0],["Taluk Office, Kinathukkadavu",0],["Taluk Office, Madukkarai",0],["Railway Station, Podanur",0],["Pillur Dam, Mettupalayam .",0],["BDO, Thondamuthur",0],["Siruvani Adivaram (Water Treatment Plant)",0],["PWD IB, (Inspection Bungalow), Makkinampatti.",0],["PWD office, Vaarappatti",0],["Coimbatore South",0],["Mettupalayam",0],["Annur",0],["Airport Peelamedu",0],["Taluk Office, Valparai",0],["Sulur",0],["Taluk Office, Pollachi",0],["Periyanaickenpalayam",0],["T.N.A.U",0],["Cincona",0],["Chinnakalar",0],["Valparai PAP",0],["Sholayar",0],["Aliyar",0],]},{name:"Cuddalore",id:"Cuddalore",data:[["Vanamadevi",15.6],["Panruti",15],["Pelandurai",13.6],["Kurinjipadi",10],["SRC Kudithangi",9],["Srimushnam",8.2],["Veppur",8],["Vadakuthu",8],["Vridhachalam",7],["Tozhudur",6],["Indian Metrology Department",5.8],["Kattumayilur",5],["Kuppanatham",5],["Collectorate",4.9],["Kilacheruvai",4],["Sethiyathope",3.2],["Me.Mathur",3],["Kothavacherry",2],["Lalpet",2],["Annamalai Nagar",1.5],["Kattumannarkoil",1.4],["Parangipettai",1],["Chidambaram",1],["Bhuvanagiri",0],["Lakkur",0],]},{name:"Dharmapuri",id:"Dharmapuri",data:[["Palacode co.op.sugar mill",0],["Subramania siva co.op sugar mill",0],["Dharmapuri",0],["Harur",0],["Pennagaram",0],["Palacode",0],["Taluk office, Pappireddipatti",0],["Hogenakkal Forest tb",0],["Marandahalli TB",0],]},{name:"Dindigul",id:"Dindigul",data:[["Palani",1],["Kamatchipuram",0.8],["VEDASANDUR",0.6],["TOBACCO STATION(VDR)",0.6],["Dindigul",0],["Natham",0],["Nilakottai",0],["Chatrapatti (Ottanchatram)",0],["Kodaikanal boat club",0],["Kodaikanal",0],]},{name:"Erode",id:"Erode",data:[["Erode",0],["Kodumudi",0],["Perundurai",0],["Bhavani",0],["Gobichettipalayam",0],["Sathyamangalam",0],["Bhavanisagar",0],["Thalavadi",0],["Nambiyur",0],["Ammapettai",0],["Chennimalai",0],["Modakkurichi",0],["Varattupallam",0],["Elanthakuttai Medu",0],["Kavundapadi",0],["Kunderipallam",0],["Kodivery",0],]},{name:"Kallakurichi",id:"Kallakurichi",data:[["Gomugi Dam (PWD)",0],["Manimutharu Dam (PWD) ...
#         ]
#     }
# });*/
#
# var galleries = document.getElementsByClassName("color_code");
# var len = galleries.length;
#
# for (var j = 0; j < len; j++) {
#     var i = galleries[j].innerHTML;
#     if (i == 0) {
#         galleries[j].style.backgroundColor = "#bfbfbf";
#     } else if (i > 0 && i <= 7.6) {
#         galleries[j].style.backgroundColor = "#DAF7A6";
#     } else if (i > 7.6 && i <= 64.5) {
#         galleries[j].style.backgroundColor = "#46C646";
#     } else if (i > 64.5 && i <= 115.6) {
#         galleries[j].style.backgroundColor = "#ffff00";
#     } else if (i > 115.6 && i <= 204.4) {
#         galleries[j].style.backgroundColor = "#ffa500";
#     } else if (i > 204.4) {
#         galleries[j].style.backgroundColor = "#ff0000";
#         galleries[j].style.color = "white";
#     }
# }
#
# var districts = [{"district_id":"17","district_name":"Ariyalur","t_district_name":"\u0b85\u0bb0\u0bbf\u0baf\u0bb2\u0bc2\u0bb0\u0bcd","district_code":"ARI","imd_nowcast_id":"56","dr_agri_id":"30","color_code":"#e8fbe1"},{"district_id":"35","district_name":"Chengalpattu","t_district_name":"\u0b9a\u0bc6\u0b99\u0bcd\u0b95\u0bb2\u0bcd\u0baa\u0b9f\u0bcd\u0b9f\u0bc1","district_code":"CGL","imd_nowcast_id":"681","dr_agri_id":"35","color_code":"#ece3fc"},{"district_id":"2","district_name":"Chennai","t_district_name":"\u0b9a\u0bc6\u0ba9\u0bcd\u0ba9\u0bc8","district_code":"CHN","imd_nowcast_id":"78","dr_agri_id":"32","color_code":"#fcebf6"},{"district_id":"12","district_name":"Coimbatore","t_district_name":"\u0b95\u0bcb\u0baf\u0bae\u0bcd\u0baa\u0bc1\u0ba4\u0bcd\u0ba4\u0bc2\u0bb0\u0bcd","district_code":"CBE","imd_nowcast_id":"55","dr_agri_id":"11","color_code":"#faf8df"},{"district_id":"18","district_name":"Cuddalore","t_district_name":"\u0b95\u0b9f\u0bb2\u0bc2\u0bb0\u0bcd","district_code":"CUD","imd_nowcast_id":"61","dr_agri_id":"4","color_code":"#ddf2fd"},{"district_id":"5","district_name":"Dharmapuri","t_district_name":"\u0ba4\u0bb0\u0bcd\u0bae\u0baa\u0bc1\u0bb0\u0bbf","district_code":"DPI","imd_nowcast_id":"70","dr_agri_id":"12","color_code":"#dee0e4"},{"district_id":"13","district_name":"Dindigul","t_district_name":"\u0ba4\u0bbf\u0ba3\u0bcd\u0b9f\u0bc1\u0b95\u0bcd\u0b95\u0bb2\u0bcd","district_code":"DGL","imd_nowcast_id":"46","dr_agri_id":"22","color_code":"#ffe3b5"},{"district_id":"10","district_name":"Erode","t_district_name":"\u0b88\u0bb0\u0bcb\u0b9f\u0bc1","district_code":"ERD","imd_nowcast_id":"64","dr_agri_id":"10","color_code":"#f9d1c7"},{"district_id":"33","district_name":"Kallakurichi","t_district_name":"\u0b95\u0bb3\u0bcd\u0bb3\u0b95\u0bcd\u0b95\u0bc1\u0bb1\u0bbf\u0b9a\u0bcd\u0b9a\u0bbf","district_code":"KAL","imd_nowcast_id":"682","dr_agri_id":"38","color_code":"#f6e7e5"},{"district_id":"3","district_name":"Kancheepuram","t_district_name":"\u0b95\u0bbe\u0b9e\u0bcd\u0b9a\u0bbf\u0baa\u0bc1\u0bb0\u0bae\u0bcd","district_code":"KPM","imd_nowcast_id":"76","dr_agri_id":"2","color_code":"#c3eefa"},{"district_id":"30","district_name":"Kanniyakumari","t_district_name":"\u0b95\u0ba9\u0bcd\u0ba9\u0bbf\u0baf\u0bbe\u0b95\u0bc1\u0bae\u0bb0\u0bbf","district_code":"KKM","imd_nowcast_id":"30","dr_agri_id":"29","color_code":"#f5f5f5"},{"district_id":"14","district_name":"Karur","t_district_name":"\u0b95\u0bb0\u0bc2\u0bb0\u0bcd","district_code":"KAR","imd_nowcast_id":"49","dr_agri_id":"15","color_code":"#d4fafa"},{"district_id":"31","district_name":"Krishnagiri","t_district_name":"\u0b95\u0bbf\u0bb0\u0bc1\u0bb7\u0bcd\u0ba3\u0b95\u0bbf\u0bb0\u0bbf","district_code":"KGI","imd_nowcast_id":"75","dr_agri_id":"13","color_code":"#fef7e2"},{"district_id":"24","district_name":"Madurai","t_district_name":"\u0bae\u0ba4\u0bc1\u0bb0\u0bc8","district_code":"MDU","imd_nowcast_id":"41","dr_agri_id":"21","color_code":"#9dcaeb"},{"district_id":"38","district_name":"Mayiladuthurai","t_district_name":"\u0bae\u0baf\u0bbf\u0bb2\u0bbe\u0b9f\u0bc1\u0ba4\u0bc1\u0bb1\u0bc8","district_code":"MYD","imd_nowcast_id":"0","dr_agri_id":"39","color_code":"#d1dac3"},{"district_id":"19","district_name":"Nagapattinam","t_district_name":"\u0ba8\u0bbe\u0b95\u0baa\u0bcd\u0baa\u0b9f\u0bcd\u0b9f\u0bbf\u0ba9\u0bae\u0bcd","district_code":"NGP","imd_nowcast_id":"47","dr_agri_id":"19","color_code":"#c3c3c3"},{"district_id":"9","district_name":"Namakkal","t_district_name":"\u0ba8\u0bbe\u0bae\u0b95\u0bcd\u0b95\u0bb2\u0bcd","district_code":"NMK","imd_nowcast_id":"59","dr_agri_id":"8","color_code":"#afd5f0"},{"district_id":"16","district_name":"Perambalur","t_district_name":"\u0baa\u0bc6\u0bb0\u0bae\u0bcd\u0baa\u0bb2\u0bc2\u0bb0\u0bcd","district_code":"PMB","imd_nowcast_id":"57","dr_agri_id":"16","color_code":"#f1e0d1"},{"district_id":"22","district_name":"Pudukkottai","t_district_name":"\u0baa\u0bc1\u0ba4\u0bc1\u0b95\u0bcd\u0b95\u0bcb\u0b9f\u0bcd\u0b9f\u0bc8","district_code":"PDK","imd_nowc ...
#
# var district_color = document.getElementsByClassName("district_color");
# var district_color_len = district_color.length;
#
# if (1 == 1) {
#     for (var j = 0; j < district_color_len; j++) {
#         var data = district_color[j].innerHTML;
#         for (var i = 0; i < districts.length; i++) {
#             if (districts[i]['district_name'] == data || districts[i]['t_district_name'] == data) {
#                 district_color[j].style.backgroundColor = districts[i]['color_code'];
#             }
#         }
#     }
# }
#
#
#
# function printDiv(test) {
#     var date = new Date();
#     var originalContents = document.body.innerHTML;
#     var win = window.open('');
#     var htmlToPrint = `<style type="text/css">
#             body {
#                 font-family: Marutham !important;
#                 text-align: justify;
#                 margin-left:50px;
#             }
#             table, tr, th, td {
#                 border:1px solid #000;
#                 border-collapse: collapse;
#                 padding:1px;
#                 width:100%;
#                 font-weight: 400;
#             }
#             @font-face {
#                 font-family: "Marutham";
#                 src: url(https://beta-tnsmart.rimes.int/assets/fonts/TAU-Marutham.ttf);
#             }
#             th{
#                 width:20%
#             }
#             td{
#                 text-align:center
#             }
#             .dot {
#               height: 15px;
#               width: 15px;
#               border-radius: 50%;
#               display: inline-block;
#               border: 1px solid #000;
#             }
#             .legend_label{
#                 padding: 2px;
#             }
#             </style>`;
#     win.document.write(
#         "<table><tr><th colspan='3'>தமிழ்நாடு பேரிடர் அபாயக் குறைப்பு முகமை </th></tr><tr><th colspan='3'>தமிழ்நாட்டில் கடந்த 24 மணி நேரமாக பெறப்பட்ட மழை அளவு  (All units are shown in mm)</th></tr><tr><th colspan='3'> From 29-Dec-2024, 08:30 AM To  30-Dec-2024, 08:30 AM</th></tr></table>"
#         );
#
#     var divToPrint = document.getElementById(test);
#     htmlToPrint += divToPrint.outerHTML;
#     htmlToPrint += '<script>document.title="tnsmart_state_rainfall_2024-12-30";window.print();<\/script>';
#     win.document.write(htmlToPrint);
#
# }
# </script>
# </body>
# </html>

# %% [markdown]
# ## Find the date value in the HTML and check if it matches today's date to proceed further.

# %%
Da = soup.find(class_ = "panel-heading")
Da
# Out:
# <div class="panel-heading" style="background-color: #f5f5f5;color:black">District wise observed Rainfall
#                     data on 30-Dec-2024</div>

# %%
Date = Da.text.strip().replace("District wise observed Rainfall\n                    data on ","")

# %%
Date
# Out:
# '30-Dec-2024'

# %%
Date[3:6]
# Out:
# 'Dec'

# %%
# Assign month str to value
month = { "Jan" : "01", "Feb" : "02", "Mar" : "03", "Apr" : "04", "May" : "05", "Jun" : "06", "Jul" : "07",
          "Aug" : "08", "Sep" : "09", "Oct" : "10", "Nov" : "11", "Dec" : "12"}
month
# Out:
# {'Jan': '01',
#  'Feb': '02',
#  'Mar': '03',
#  'Apr': '04',
#  'May': '05',
#  'Jun': '06',
#  'Jul': '07',
#  'Aug': '08',
#  'Sep': '09',
#  'Oct': '10',
#  'Nov': '11',
#  'Dec': '12'}

# %%
month[Date[3:6]]
# Out:
# '12'

# %%
# Replace the str to numeric value
Da = Date.replace(Date[3:6],month[Date[3:6]])
Da
# Out:
# '30-12-2024'

# %%
# Date Values
y = int(Da[6:11])
m = int(Da[3:5])
d = int(Da[0:2])

# %%
Today_Date =datetime.date(y,m,d)
Today_Date
# Out:
# datetime.date(2024, 12, 30)

# %%
date.today()
# Out:
# datetime.date(2024, 12, 30)

# %%
Today_Date == date.today()
# Out:
# True

# %% [markdown]
# ## Gather the table data from the HTML for further processing.

# %%
# Find the necessary data
if ((Today_Date == date.today())):
    print("Date match with current Date")
    table = soup.find('table', id = "data_table")
else:
    print("Date not matched")
    table = []
# Out:
# Date match with current Date

# %% [markdown]
# ### Cheking the table title based on the provided data or context.

# %%
table_th = table.find_all('th')[:5]
table_th
# Out:
# [<th>வரிசை எண்</th>,
#  <th>உரிமையாளர்</th>,
#  <th>மாவட்டம்</th>,
#  <th>மழைமானி நிலையம்</th>,
#  <th>பதிவான மழை அளவு (மி.மீ.)</th>]

# %%
table_title = [table_th.text.strip('\n') for table_th in table_th]
table_title
# Out:
# ['வரிசை எண்',
#  'உரிமையாளர்',
#  'மாவட்டம்',
#  'மழைமானி நிலையம்',
#  'பதிவான மழை அளவு (மி.மீ.)']

# %%
len(table_title)
# Out:
# 5

# %%
df = pd.DataFrame(columns = table_title)

# %%
df
# Out:
# Empty DataFrame
# Columns: [வரிசை எண், உரிமையாளர், மாவட்டம், மழைமானி நிலையம், பதிவான மழை அளவு (மி.மீ.)]
# Index: []

# %% [markdown]
# ## Gather the table data from the HTML document for processing.

# %%
table
# Out:
# <table id="data_table">
# <thead>
# <tr>
# <th>வரிசை எண்</th>
# <th>உரிமையாளர்</th>
# <th>மாவட்டம்</th>
# <th>மழைமானி நிலையம்</th>
# <th>பதிவான மழை அளவு (மி.மீ.)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Suthamalli dam</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Kuruvadi</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Jayankondam taluk office</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>PWD Office, Sendurai</th>
# <td class="color_code">
#                             3.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Taluk Office, Andimadam</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>Ariyalur Taluk Office</th>
# <td class="color_code">
#                             2.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>THIRUMANUR  PWD OFFICE (R.C.DIVISION)</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Ariyalur</th>
# <th>T.Palur Panchayat Union 0ffice</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>25.1</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>3.14</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Taluk Office, Thirukalukundram</th>
# <td class="color_code">
#                             45</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Mammallapuram PWD bungalow</th>
# <td class="color_code">
#                             38</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Keelampakkam</th>
# <td class="color_code">
#                             14.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Taluk Office, Thiruporur</th>
# <td class="color_code">
#                             10</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Chengalpattu</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Madurantakam taluk office</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Chengalpattu</th>
# <th>Taluk Office, Tambaram</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>CMWSSB</th>
# <th class="district_color">Chengalpattu</th>
# <th>Alandur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>120.2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>13.36</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 15 Uthandi</th>
# <td class="color_code">
#                             15.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 15 Sholinganallur</th>
# <td class="color_code">
#                             5.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 12 Meenambakkam</th>
# <td class="color_code">
#                             3.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 12 Alandhur</th>
# <td class="color_code">
#                             3.3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Chennai</th>
# <th>Sholinganallur</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 09 Ice House</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Chennai</th>
# <th>Alandur</th>
# <td class="color_code">
#                             2.9</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 13 Raja Annamalai puram</th>
# <td class="color_code">
#                             2.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 14 Perungudi</th>
# <td class="color_code">
#                             2.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>CMWSSB</th>
# <th class="district_color">Chennai</th>
# <th>Sholinganallur</th>
# <td class="color_code">
#                             2.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Chennai</th>
# <th>Anna university</th>
# <td class="color_code">
#                             1.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 13 Adyar</th>
# <td class="color_code">
#                             1.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 14 Madipakkam</th>
# <td class="color_code">
#                             1.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>GCC</th>
# <th class="district_color">Chennai</th>
# <th>Zone 13 Velachery</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>CMWSSB</th>
# <th class="district_color">Chennai</th>
# <th>Perungudi</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>CMWSSB</th>
# <th class="district_color">Chennai</th>
# <th>Adyar</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>51.7</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.94</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Vanamadevi</th>
# <td class="color_code">
#                             15.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Panruti</th>
# <td class="color_code">
#                             15</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Pelandurai</th>
# <td class="color_code">
#                             13.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kurinjipadi</th>
# <td class="color_code">
#                             10</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>SRC Kudithangi</th>
# <td class="color_code">
#                             9</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Srimushnam</th>
# <td class="color_code">
#                             8.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Veppur</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Vadakuthu</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Vridhachalam</th>
# <td class="color_code">
#                             7</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Tozhudur</th>
# <td class="color_code">
#                             6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Indian Metrology Department</th>
# <td class="color_code">
#                             5.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kattumayilur</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kuppanatham</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Collectorate</th>
# <td class="color_code">
#                             4.9</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kilacheruvai</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Sethiyathope</th>
# <td class="color_code">
#                             3.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>17</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Me.Mathur</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>18</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kothavacherry</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>19</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Lalpet</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>20</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Annamalai Nagar</th>
# <td class="color_code">
#                             1.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>21</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Kattumannarkoil</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>22</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Parangipettai</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>23</th>
# <th>Revenue</th>
# <th class="district_color">Cuddalore</th>
# <th>Chidambaram</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>140.2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>5.61</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>Palani</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>Kamatchipuram</th>
# <td class="color_code">
#                             0.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>VEDASANDUR</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Dindigul</th>
# <th>TOBACCO STATION(VDR)</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>3</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Kancheepuram</th>
# <th>Sriperumbadur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Kancheepuram</th>
# <th>Kancheepuram taluk office</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>3</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Madurai</th>
# <th>Elumalai</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>0.4</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.02</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Mayiladuthurai</th>
# <th>Mayiladuthurai</th>
# <td class="color_code">
#                             4.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Mayiladuthurai</th>
# <th>Sirkali</th>
# <td class="color_code">
#                             2.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Mayiladuthurai</th>
# <th>Sembanarkoil (PWD)</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>8.2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>1.37</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Nagapattinam</th>
# <td class="color_code">
#                             81.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Velankanni</th>
# <td class="color_code">
#                             72.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Thirupoondi</th>
# <td class="color_code">
#                             13.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Kodiayakarai</th>
# <td class="color_code">
#                             10.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Vedaranyam</th>
# <td class="color_code">
#                             9.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Thirukuvalai</th>
# <td class="color_code">
#                             7</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Nagapattinam</th>
# <th>Thalanayar</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>198.5</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>28.36</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Puthu vettakudi</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Labbaikudikadu</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Agaram seegoor</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Eraiyur</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>VEPPANTHATTAI</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>V.KALATHUR</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Chettikulam</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Perambalur</th>
# <th>Perambalur</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>23</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>2.09</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Gandarvakottai</th>
# <td class="color_code">
#                             8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Karaiyur</th>
# <td class="color_code">
#                             5.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Perungalur</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Malaiyur</th>
# <td class="color_code">
#                             4.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Alangudi</th>
# <td class="color_code">
#                             4.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Pudukkottai</th>
# <td class="color_code">
#                             4.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Karambakudi</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Kudimiyanmalai</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>THIRUMAYAM</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Manamelkudi</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Annavasal</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Pudukkottai</th>
# <th>Keeranur</th>
# <td class="color_code">
#                             1.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>47.5</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>1.98</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>Mandapam</th>
# <td class="color_code">
#                             1.1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>pamban</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>Thangachimadam</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Ramanathapuram</th>
# <th>Rameswaram</th>
# <td class="color_code">
#                             0.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>3.9</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.24</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Salem</th>
# <th>Yercaud</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>1</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.06</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Sivagangai</th>
# <th>Thiruppathur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.22</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Orathanad</th>
# <td class="color_code">
#                             25</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Neivasal Thenpathi</th>
# <td class="color_code">
#                             20</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Vettikadu</th>
# <td class="color_code">
#                             19.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Madukkur</th>
# <td class="color_code">
#                             15.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Kurungulam</th>
# <td class="color_code">
#                             11</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Vallam</th>
# <td class="color_code">
#                             7</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thirukkattupalli</th>
# <td class="color_code">
#                             3.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Ayyampettai</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thiruvidaimaruthur</th>
# <td class="color_code">
#                             2.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Papanasam</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Manjalaru</th>
# <td class="color_code">
#                             1.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Lower Anaicut</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Echanviduthi</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Taluk Office, Kumbakonam</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thiruvaiyaru</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Pattukkottai</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>17</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Grand Anaicut</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>18</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Thanjavur</th>
# <td class="color_code">
#                             0.5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>19</th>
# <th>Revenue</th>
# <th class="district_color">Thanjavur</th>
# <th>Adirampatnam</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>117.7</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>5.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Thenparanadu</th>
# <td class="color_code">
#                             14</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Tiruchirappalli Town</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Thuvakudi</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Tiruchirappalli Junction</th>
# <td class="color_code">
#                             0.6</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Thiruchirappalli</th>
# <th>Tiruchirappalli Airport</th>
# <td class="color_code">
#                             0.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>19</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.79</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Needamangalam</th>
# <td class="color_code">
#                             35.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Mannargudi</th>
# <td class="color_code">
#                             32</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Taluk Office , Tiruvarur</th>
# <td class="color_code">
#                             31</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Kudavasal</th>
# <td class="color_code">
#                             19.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Taluk Office, Nannilam</th>
# <td class="color_code">
#                             14.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Pandavaiyaru</th>
# <td class="color_code">
#                             12.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Taluk Office, Thiruthuraipoondi</th>
# <td class="color_code">
#                             10.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Thiruvarur</th>
# <th>Sub Registrar Office, Muthupettai</th>
# <td class="color_code">
#                             3.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>158</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>17.56</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Oothu</th>
# <td class="color_code">
#                             34</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Nalumukku</th>
# <td class="color_code">
#                             30</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Kakkachi</th>
# <td class="color_code">
#                             21</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Manjolai</th>
# <td class="color_code">
#                             14</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Papanasam</th>
# <td class="color_code">
#                             4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Kannadian Anicut</th>
# <td class="color_code">
#                             3.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Ambasamudram</th>
# <td class="color_code">
#                             2.8</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Cheranmahadevi</th>
# <td class="color_code">
#                             1.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Manimutharu</th>
# <td class="color_code">
#                             1.2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Tirunelveli</th>
# <th>Kalakadu</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>112.8</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>6.27</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Tiruppur</th>
# <th>Udumalpet</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Tiruppur</th>
# <th>Madathukulam</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>2</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Tiruvannamalai</th>
# <th>Kilpennathur</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Tiruvannamalai</th>
# <th>Vembakkam</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>7</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>0.58</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>1</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-2 Valavanur</th>
# <td class="color_code">
#                             12</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>2</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>VILUPPURAM</th>
# <td class="color_code">
#                             10</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>3</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-2 Koliyanur</th>
# <td class="color_code">
#                             10</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>4</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>TINDIVANAM</th>
# <td class="color_code">
#                             5</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>5</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-3 Semmedu</th>
# <td class="color_code">
#                             4.4</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>6</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-2 Soorapattu</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>7</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>Marakkanam</th>
# <td class="color_code">
#                             3</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>8</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>VANUR</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>9</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-2 Mundiyampakkam</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>10</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-2 Kedar</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>11</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>Gingee</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>12</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-3 Avalurpettai</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>13</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>SCS MILL Arasoor</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>14</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>SCS MILL Thiruvennainallur</th>
# <td class="color_code">
#                             2</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>15</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-2 Kanjanur</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th>16</th>
# <th>Revenue</th>
# <th class="district_color">Villupuram</th>
# <th>RSCL-3 Valathy</th>
# <td class="color_code">
#                             1</td>
# </tr>
# </tbody>
# <tbody>
# <tr>
# <th colspan="4">Total rainfall</th>
# <td>63.4</td>
# </tr>
# <tr>
# <th colspan="4">Average rainfall</th>
# <td>3.02</td>
# </tr>
# </tbody>
# <tfoot>
# <tr align="center">
# <td colspan="5">
# <label class="legend_label"><span class="dot" style="background-color: #ffffff;"></span> No
#                                 rain</label>
# <label class="legend_label"><span class="dot" style="background-color: #bfbfbf;"></span>Very
#                                 light rain</label>
# <label class="legend_label"><span class="dot" style="background-color: #DAF7A6;"></span>Light rain</label>
# <label class="legend_label"><span class="dot" style="background-color: #46C646;"></span>Moderate rain</label>
# <label class="legend_label"><span class="dot" style="background-color: #FFFF00;"></span>Heavy rain</label>
# <label class="legend_label"><span class="dot" style="background-color: #FFA500;"></span>Very
#                                 heavy rain</label>
# <label class="legend_label"><span class="dot" style="background-color: #FF0000;"></span>Extreme heavy rain</label>
# </td>
# </tr>
# </tfoot>
# </table>

# %%
table_tr = table.find_all('tr')
table_tr
# Out:
# [<tr>
#  <th>வரிசை எண்</th>
#  <th>உரிமையாளர்</th>
#  <th>மாவட்டம்</th>
#  <th>மழைமானி நிலையம்</th>
#  <th>பதிவான மழை அளவு (மி.மீ.)</th>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>Suthamalli dam</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>Kuruvadi</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>Jayankondam taluk office</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>PWD Office, Sendurai</th>
#  <td class="color_code">
#                              3.6</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>Taluk Office, Andimadam</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>Ariyalur Taluk Office</th>
#  <td class="color_code">
#                              2.5</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>THIRUMANUR  PWD OFFICE (R.C.DIVISION)</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Ariyalur</th>
#  <th>T.Palur Panchayat Union 0ffice</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>25.1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>3.14</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Taluk Office, Thirukalukundram</th>
#  <td class="color_code">
#                              45</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Mammallapuram PWD bungalow</th>
#  <td class="color_code">
#                              38</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Keelampakkam</th>
#  <td class="color_code">
#                              14.2</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Taluk Office, Thiruporur</th>
#  <td class="color_code">
#                              10</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Chengalpattu</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Madurantakam taluk office</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Taluk Office, Tambaram</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>CMWSSB</th>
#  <th class="district_color">Chengalpattu</th>
#  <th>Alandur</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>120.2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>13.36</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 15 Uthandi</th>
#  <td class="color_code">
#                              15.6</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 15 Sholinganallur</th>
#  <td class="color_code">
#                              5.6</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 12 Meenambakkam</th>
#  <td class="color_code">
#                              3.6</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 12 Alandhur</th>
#  <td class="color_code">
#                              3.3</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Chennai</th>
#  <th>Sholinganallur</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 09 Ice House</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Chennai</th>
#  <th>Alandur</th>
#  <td class="color_code">
#                              2.9</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 13 Raja Annamalai puram</th>
#  <td class="color_code">
#                              2.4</td>
#  </tr>,
#  <tr>
#  <th>9</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 14 Perungudi</th>
#  <td class="color_code">
#                              2.4</td>
#  </tr>,
#  <tr>
#  <th>10</th>
#  <th>CMWSSB</th>
#  <th class="district_color">Chennai</th>
#  <th>Sholinganallur</th>
#  <td class="color_code">
#                              2.2</td>
#  </tr>,
#  <tr>
#  <th>11</th>
#  <th>Revenue</th>
#  <th class="district_color">Chennai</th>
#  <th>Anna university</th>
#  <td class="color_code">
#                              1.8</td>
#  </tr>,
#  <tr>
#  <th>12</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 13 Adyar</th>
#  <td class="color_code">
#                              1.8</td>
#  </tr>,
#  <tr>
#  <th>13</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 14 Madipakkam</th>
#  <td class="color_code">
#                              1.5</td>
#  </tr>,
#  <tr>
#  <th>14</th>
#  <th>GCC</th>
#  <th class="district_color">Chennai</th>
#  <th>Zone 13 Velachery</th>
#  <td class="color_code">
#                              1.2</td>
#  </tr>,
#  <tr>
#  <th>15</th>
#  <th>CMWSSB</th>
#  <th class="district_color">Chennai</th>
#  <th>Perungudi</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>16</th>
#  <th>CMWSSB</th>
#  <th class="district_color">Chennai</th>
#  <th>Adyar</th>
#  <td class="color_code">
#                              0.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>51.7</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.94</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Vanamadevi</th>
#  <td class="color_code">
#                              15.6</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Panruti</th>
#  <td class="color_code">
#                              15</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Pelandurai</th>
#  <td class="color_code">
#                              13.6</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Kurinjipadi</th>
#  <td class="color_code">
#                              10</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>SRC Kudithangi</th>
#  <td class="color_code">
#                              9</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Srimushnam</th>
#  <td class="color_code">
#                              8.2</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Veppur</th>
#  <td class="color_code">
#                              8</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Vadakuthu</th>
#  <td class="color_code">
#                              8</td>
#  </tr>,
#  <tr>
#  <th>9</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Vridhachalam</th>
#  <td class="color_code">
#                              7</td>
#  </tr>,
#  <tr>
#  <th>10</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Tozhudur</th>
#  <td class="color_code">
#                              6</td>
#  </tr>,
#  <tr>
#  <th>11</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Indian Metrology Department</th>
#  <td class="color_code">
#                              5.8</td>
#  </tr>,
#  <tr>
#  <th>12</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Kattumayilur</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>13</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Kuppanatham</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>14</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Collectorate</th>
#  <td class="color_code">
#                              4.9</td>
#  </tr>,
#  <tr>
#  <th>15</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Kilacheruvai</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>16</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Sethiyathope</th>
#  <td class="color_code">
#                              3.2</td>
#  </tr>,
#  <tr>
#  <th>17</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Me.Mathur</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>18</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Kothavacherry</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>19</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Lalpet</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>20</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Annamalai Nagar</th>
#  <td class="color_code">
#                              1.5</td>
#  </tr>,
#  <tr>
#  <th>21</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Kattumannarkoil</th>
#  <td class="color_code">
#                              1.4</td>
#  </tr>,
#  <tr>
#  <th>22</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Parangipettai</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>23</th>
#  <th>Revenue</th>
#  <th class="district_color">Cuddalore</th>
#  <th>Chidambaram</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>140.2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>5.61</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Dindigul</th>
#  <th>Palani</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Dindigul</th>
#  <th>Kamatchipuram</th>
#  <td class="color_code">
#                              0.8</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Dindigul</th>
#  <th>VEDASANDUR</th>
#  <td class="color_code">
#                              0.6</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Dindigul</th>
#  <th>TOBACCO STATION(VDR)</th>
#  <td class="color_code">
#                              0.6</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>3</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.3</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Kancheepuram</th>
#  <th>Sriperumbadur</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Kancheepuram</th>
#  <th>Kancheepuram taluk office</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>3</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.5</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Madurai</th>
#  <th>Elumalai</th>
#  <td class="color_code">
#                              0.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>0.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.02</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Mayiladuthurai</th>
#  <th>Mayiladuthurai</th>
#  <td class="color_code">
#                              4.2</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Mayiladuthurai</th>
#  <th>Sirkali</th>
#  <td class="color_code">
#                              2.6</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Mayiladuthurai</th>
#  <th>Sembanarkoil (PWD)</th>
#  <td class="color_code">
#                              1.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>8.2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>1.37</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Nagapattinam</th>
#  <td class="color_code">
#                              81.4</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Velankanni</th>
#  <td class="color_code">
#                              72.6</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Thirupoondi</th>
#  <td class="color_code">
#                              13.2</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Kodiayakarai</th>
#  <td class="color_code">
#                              10.8</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Vedaranyam</th>
#  <td class="color_code">
#                              9.5</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Thirukuvalai</th>
#  <td class="color_code">
#                              7</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Nagapattinam</th>
#  <th>Thalanayar</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>198.5</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>28.36</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>Puthu vettakudi</th>
#  <td class="color_code">
#                              8</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>Labbaikudikadu</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>Agaram seegoor</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>Eraiyur</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>VEPPANTHATTAI</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>V.KALATHUR</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>Chettikulam</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Perambalur</th>
#  <th>Perambalur</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>23</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>2.09</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Gandarvakottai</th>
#  <td class="color_code">
#                              8</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Karaiyur</th>
#  <td class="color_code">
#                              5.2</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Perungalur</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Malaiyur</th>
#  <td class="color_code">
#                              4.6</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Alangudi</th>
#  <td class="color_code">
#                              4.6</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Pudukkottai</th>
#  <td class="color_code">
#                              4.5</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Karambakudi</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Kudimiyanmalai</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>9</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>THIRUMAYAM</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>10</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Manamelkudi</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>11</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Annavasal</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>12</th>
#  <th>Revenue</th>
#  <th class="district_color">Pudukkottai</th>
#  <th>Keeranur</th>
#  <td class="color_code">
#                              1.6</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>47.5</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>1.98</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Ramanathapuram</th>
#  <th>Mandapam</th>
#  <td class="color_code">
#                              1.1</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Ramanathapuram</th>
#  <th>pamban</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Ramanathapuram</th>
#  <th>Thangachimadam</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Ramanathapuram</th>
#  <th>Rameswaram</th>
#  <td class="color_code">
#                              0.8</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>3.9</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.24</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Salem</th>
#  <th>Yercaud</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.06</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Sivagangai</th>
#  <th>Thiruppathur</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.22</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Orathanad</th>
#  <td class="color_code">
#                              25</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Neivasal Thenpathi</th>
#  <td class="color_code">
#                              20</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Vettikadu</th>
#  <td class="color_code">
#                              19.6</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Madukkur</th>
#  <td class="color_code">
#                              15.6</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Kurungulam</th>
#  <td class="color_code">
#                              11</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Vallam</th>
#  <td class="color_code">
#                              7</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Thirukkattupalli</th>
#  <td class="color_code">
#                              3.2</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Ayyampettai</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>9</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Thiruvidaimaruthur</th>
#  <td class="color_code">
#                              2.2</td>
#  </tr>,
#  <tr>
#  <th>10</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Papanasam</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>11</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Manjalaru</th>
#  <td class="color_code">
#                              1.8</td>
#  </tr>,
#  <tr>
#  <th>12</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Lower Anaicut</th>
#  <td class="color_code">
#                              1.4</td>
#  </tr>,
#  <tr>
#  <th>13</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Echanviduthi</th>
#  <td class="color_code">
#                              1.2</td>
#  </tr>,
#  <tr>
#  <th>14</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Taluk Office, Kumbakonam</th>
#  <td class="color_code">
#                              1.2</td>
#  </tr>,
#  <tr>
#  <th>15</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Thiruvaiyaru</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>16</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Pattukkottai</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>17</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Grand Anaicut</th>
#  <td class="color_code">
#                              0.6</td>
#  </tr>,
#  <tr>
#  <th>18</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Thanjavur</th>
#  <td class="color_code">
#                              0.5</td>
#  </tr>,
#  <tr>
#  <th>19</th>
#  <th>Revenue</th>
#  <th class="district_color">Thanjavur</th>
#  <th>Adirampatnam</th>
#  <td class="color_code">
#                              0.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>117.7</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>5.6</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruchirappalli</th>
#  <th>Thenparanadu</th>
#  <td class="color_code">
#                              14</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruchirappalli</th>
#  <th>Tiruchirappalli Town</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruchirappalli</th>
#  <th>Thuvakudi</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruchirappalli</th>
#  <th>Tiruchirappalli Junction</th>
#  <td class="color_code">
#                              0.6</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruchirappalli</th>
#  <th>Tiruchirappalli Airport</th>
#  <td class="color_code">
#                              0.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>19</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.79</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Needamangalam</th>
#  <td class="color_code">
#                              35.4</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Mannargudi</th>
#  <td class="color_code">
#                              32</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Taluk Office , Tiruvarur</th>
#  <td class="color_code">
#                              31</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Kudavasal</th>
#  <td class="color_code">
#                              19.4</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Taluk Office, Nannilam</th>
#  <td class="color_code">
#                              14.2</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Pandavaiyaru</th>
#  <td class="color_code">
#                              12.4</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Taluk Office, Thiruthuraipoondi</th>
#  <td class="color_code">
#                              10.4</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Thiruvarur</th>
#  <th>Sub Registrar Office, Muthupettai</th>
#  <td class="color_code">
#                              3.2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>158</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>17.56</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Oothu</th>
#  <td class="color_code">
#                              34</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Nalumukku</th>
#  <td class="color_code">
#                              30</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Kakkachi</th>
#  <td class="color_code">
#                              21</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Manjolai</th>
#  <td class="color_code">
#                              14</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Papanasam</th>
#  <td class="color_code">
#                              4</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Kannadian Anicut</th>
#  <td class="color_code">
#                              3.4</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Ambasamudram</th>
#  <td class="color_code">
#                              2.8</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Cheranmahadevi</th>
#  <td class="color_code">
#                              1.4</td>
#  </tr>,
#  <tr>
#  <th>9</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Manimutharu</th>
#  <td class="color_code">
#                              1.2</td>
#  </tr>,
#  <tr>
#  <th>10</th>
#  <th>Revenue</th>
#  <th class="district_color">Tirunelveli</th>
#  <th>Kalakadu</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>112.8</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>6.27</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Tiruppur</th>
#  <th>Udumalpet</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Tiruppur</th>
#  <th>Madathukulam</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.1</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Tiruvannamalai</th>
#  <th>Kilpennathur</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Tiruvannamalai</th>
#  <th>Vembakkam</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>7</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>0.58</td>
#  </tr>,
#  <tr>
#  <th>1</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-2 Valavanur</th>
#  <td class="color_code">
#                              12</td>
#  </tr>,
#  <tr>
#  <th>2</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>VILUPPURAM</th>
#  <td class="color_code">
#                              10</td>
#  </tr>,
#  <tr>
#  <th>3</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-2 Koliyanur</th>
#  <td class="color_code">
#                              10</td>
#  </tr>,
#  <tr>
#  <th>4</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>TINDIVANAM</th>
#  <td class="color_code">
#                              5</td>
#  </tr>,
#  <tr>
#  <th>5</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-3 Semmedu</th>
#  <td class="color_code">
#                              4.4</td>
#  </tr>,
#  <tr>
#  <th>6</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-2 Soorapattu</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>7</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>Marakkanam</th>
#  <td class="color_code">
#                              3</td>
#  </tr>,
#  <tr>
#  <th>8</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>VANUR</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>9</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-2 Mundiyampakkam</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>10</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-2 Kedar</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>11</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>Gingee</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>12</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-3 Avalurpettai</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>13</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>SCS MILL Arasoor</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>14</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>SCS MILL Thiruvennainallur</th>
#  <td class="color_code">
#                              2</td>
#  </tr>,
#  <tr>
#  <th>15</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-2 Kanjanur</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th>16</th>
#  <th>Revenue</th>
#  <th class="district_color">Villupuram</th>
#  <th>RSCL-3 Valathy</th>
#  <td class="color_code">
#                              1</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Total rainfall</th>
#  <td>63.4</td>
#  </tr>,
#  <tr>
#  <th colspan="4">Average rainfall</th>
#  <td>3.02</td>
#  </tr>,
#  <tr align="center">
#  <td colspan="5">
#  <label class="legend_label"><span class="dot" style="background-color: #ffffff;"></span> No
#                                  rain</label>
#  <label class="legend_label"><span class="dot" style="background-color: #bfbfbf;"></span>Very
#                                  light rain</label>
#  <label class="legend_label"><span class="dot" style="background-color: #DAF7A6;"></span>Light rain</label>
#  <label class="legend_label"><span class="dot" style="background-color: #46C646;"></span>Moderate rain</label>
#  <label class="legend_label"><span class="dot" style="background-color: #FFFF00;"></span>Heavy rain</label>
#  <label class="legend_label"><span class="dot" style="background-color: #FFA500;"></span>Very
#                                  heavy rain</label>
#  <label class="legend_label"><span class="dot" style="background-color: #FF0000;"></span>Extreme heavy rain</label>
#  </td>
#  </tr>]

# %%
# Strip the value datas
list = [table_tr.text.strip().replace("\n\n", ",") for table_tr in table_tr][1:]
list
# Out:
# ['1\nRevenue\nAriyalur\nSuthamalli dam,                            5',
#  '2\nRevenue\nAriyalur\nKuruvadi,                            4',
#  '3\nRevenue\nAriyalur\nJayankondam taluk office,                            4',
#  '4\nRevenue\nAriyalur\nPWD Office, Sendurai,                            3.6',
#  '5\nRevenue\nAriyalur\nTaluk Office, Andimadam,                            3',
#  '6\nRevenue\nAriyalur\nAriyalur Taluk Office,                            2.5',
#  '7\nRevenue\nAriyalur\nTHIRUMANUR  PWD OFFICE (R.C.DIVISION),                            2',
#  '8\nRevenue\nAriyalur\nT.Palur Panchayat Union 0ffice,                            1',
#  'Total rainfall\n25.1',
#  'Average rainfall\n3.14',
#  '1\nRevenue\nChengalpattu\nTaluk Office, Thirukalukundram,                            45',
#  '2\nRevenue\nChengalpattu\nMammallapuram PWD bungalow,                            38',
#  '3\nRevenue\nChengalpattu\nKeelampakkam,                            14.2',
#  '4\nRevenue\nChengalpattu\nTaluk Office, Thiruporur,                            10',
#  '5\nRevenue\nChengalpattu\nChengalpattu,                            5',
#  '6\nRevenue\nChengalpattu\nMadurantakam taluk office,                            4',
#  '7\nRevenue\nChengalpattu\nTaluk Office, Tambaram,                            2',
#  '8\nCMWSSB\nChengalpattu\nAlandur,                            2',
#  'Total rainfall\n120.2',
#  'Average rainfall\n13.36',
#  '1\nGCC\nChennai\nZone 15 Uthandi,                            15.6',
#  '2\nGCC\nChennai\nZone 15 Sholinganallur,                            5.6',
#  '3\nGCC\nChennai\nZone 12 Meenambakkam,                            3.6',
#  '4\nGCC\nChennai\nZone 12 Alandhur,                            3.3',
#  '5\nRevenue\nChennai\nSholinganallur,                            3',
#  '6\nGCC\nChennai\nZone 09 Ice House,                            3',
#  '7\nRevenue\nChennai\nAlandur,                            2.9',
#  '8\nGCC\nChennai\nZone 13 Raja Annamalai puram,                            2.4',
#  '9\nGCC\nChennai\nZone 14 Perungudi,                            2.4',
#  '10\nCMWSSB\nChennai\nSholinganallur,                            2.2',
#  '11\nRevenue\nChennai\nAnna university,                            1.8',
#  '12\nGCC\nChennai\nZone 13 Adyar,                            1.8',
#  '13\nGCC\nChennai\nZone 14 Madipakkam,                            1.5',
#  '14\nGCC\nChennai\nZone 13 Velachery,                            1.2',
#  '15\nCMWSSB\nChennai\nPerungudi,                            1',
#  '16\nCMWSSB\nChennai\nAdyar,                            0.4',
#  'Total rainfall\n51.7',
#  'Average rainfall\n0.94',
#  '1\nRevenue\nCuddalore\nVanamadevi,                            15.6',
#  '2\nRevenue\nCuddalore\nPanruti,                            15',
#  '3\nRevenue\nCuddalore\nPelandurai,                            13.6',
#  '4\nRevenue\nCuddalore\nKurinjipadi,                            10',
#  '5\nRevenue\nCuddalore\nSRC Kudithangi,                            9',
#  '6\nRevenue\nCuddalore\nSrimushnam,                            8.2',
#  '7\nRevenue\nCuddalore\nVeppur,                            8',
#  '8\nRevenue\nCuddalore\nVadakuthu,                            8',
#  '9\nRevenue\nCuddalore\nVridhachalam,                            7',
#  '10\nRevenue\nCuddalore\nTozhudur,                            6',
#  '11\nRevenue\nCuddalore\nIndian Metrology Department,                            5.8',
#  '12\nRevenue\nCuddalore\nKattumayilur,                            5',
#  '13\nRevenue\nCuddalore\nKuppanatham,                            5',
#  '14\nRevenue\nCuddalore\nCollectorate,                            4.9',
#  '15\nRevenue\nCuddalore\nKilacheruvai,                            4',
#  '16\nRevenue\nCuddalore\nSethiyathope,                            3.2',
#  '17\nRevenue\nCuddalore\nMe.Mathur,                            3',
#  '18\nRevenue\nCuddalore\nKothavacherry,                            2',
#  '19\nRevenue\nCuddalore\nLalpet,                            2',
#  '20\nRevenue\nCuddalore\nAnnamalai Nagar,                            1.5',
#  '21\nRevenue\nCuddalore\nKattumannarkoil,                            1.4',
#  '22\nRevenue\nCuddalore\nParangipettai,                            1',
#  '23\nRevenue\nCuddalore\nChidambaram,                            1',
#  'Total rainfall\n140.2',
#  'Average rainfall\n5.61',
#  '1\nRevenue\nDindigul\nPalani,                            1',
#  '2\nRevenue\nDindigul\nKamatchipuram,                            0.8',
#  '3\nRevenue\nDindigul\nVEDASANDUR,                            0.6',
#  '4\nRevenue\nDindigul\nTOBACCO STATION(VDR),                            0.6',
#  'Total rainfall\n3',
#  'Average rainfall\n0.3',
#  '1\nRevenue\nKancheepuram\nSriperumbadur,                            2',
#  '2\nRevenue\nKancheepuram\nKancheepuram taluk office,                            1',
#  'Total rainfall\n3',
#  'Average rainfall\n0.5',
#  '1\nRevenue\nMadurai\nElumalai,                            0.4',
#  'Total rainfall\n0.4',
#  'Average rainfall\n0.02',
#  '1\nRevenue\nMayiladuthurai\nMayiladuthurai,                            4.2',
#  '2\nRevenue\nMayiladuthurai\nSirkali,                            2.6',
#  '3\nRevenue\nMayiladuthurai\nSembanarkoil (PWD),                            1.4',
#  'Total rainfall\n8.2',
#  'Average rainfall\n1.37',
#  '1\nRevenue\nNagapattinam\nNagapattinam,                            81.4',
#  '2\nRevenue\nNagapattinam\nVelankanni,                            72.6',
#  '3\nRevenue\nNagapattinam\nThirupoondi,                            13.2',
#  '4\nRevenue\nNagapattinam\nKodiayakarai,                            10.8',
#  '5\nRevenue\nNagapattinam\nVedaranyam,                            9.5',
#  '6\nRevenue\nNagapattinam\nThirukuvalai,                            7',
#  '7\nRevenue\nNagapattinam\nThalanayar,                            4',
#  'Total rainfall\n198.5',
#  'Average rainfall\n28.36',
#  '1\nRevenue\nPerambalur\nPuthu vettakudi,                            8',
#  '2\nRevenue\nPerambalur\nLabbaikudikadu,                            3',
#  '3\nRevenue\nPerambalur\nAgaram seegoor,                            3',
#  '4\nRevenue\nPerambalur\nEraiyur,                            3',
#  '5\nRevenue\nPerambalur\nVEPPANTHATTAI,                            2',
#  '6\nRevenue\nPerambalur\nV.KALATHUR,                            2',
#  '7\nRevenue\nPerambalur\nChettikulam,                            1',
#  '8\nRevenue\nPerambalur\nPerambalur,                            1',
#  'Total rainfall\n23',
#  'Average rainfall\n2.09',
#  '1\nRevenue\nPudukkottai\nGandarvakottai,                            8',
#  '2\nRevenue\nPudukkottai\nKaraiyur,                            5.2',
#  '3\nRevenue\nPudukkottai\nPerungalur,                            5',
#  '4\nRevenue\nPudukkottai\nMalaiyur,                            4.6',
#  '5\nRevenue\nPudukkottai\nAlangudi,                            4.6',
#  '6\nRevenue\nPudukkottai\nPudukkottai,                            4.5',
#  '7\nRevenue\nPudukkottai\nKarambakudi,                            4',
#  '8\nRevenue\nPudukkottai\nKudimiyanmalai,                            4',
#  '9\nRevenue\nPudukkottai\nTHIRUMAYAM,                            2',
#  '10\nRevenue\nPudukkottai\nManamelkudi,                            2',
#  '11\nRevenue\nPudukkottai\nAnnavasal,                            2',
#  '12\nRevenue\nPudukkottai\nKeeranur,                            1.6',
#  'Total rainfall\n47.5',
#  'Average rainfall\n1.98',
#  '1\nRevenue\nRamanathapuram\nMandapam,                            1.1',
#  '2\nRevenue\nRamanathapuram\npamban,                            1',
#  '3\nRevenue\nRamanathapuram\nThangachimadam,                            1',
#  '4\nRevenue\nRamanathapuram\nRameswaram,                            0.8',
#  'Total rainfall\n3.9',
#  'Average rainfall\n0.24',
#  '1\nRevenue\nSalem\nYercaud,                            1',
#  'Total rainfall\n1',
#  'Average rainfall\n0.06',
#  '1\nRevenue\nSivagangai\nThiruppathur,                            2',
#  'Total rainfall\n2',
#  'Average rainfall\n0.22',
#  '1\nRevenue\nThanjavur\nOrathanad,                            25',
#  '2\nRevenue\nThanjavur\nNeivasal Thenpathi,                            20',
#  '3\nRevenue\nThanjavur\nVettikadu,                            19.6',
#  '4\nRevenue\nThanjavur\nMadukkur,                            15.6',
#  '5\nRevenue\nThanjavur\nKurungulam,                            11',
#  '6\nRevenue\nThanjavur\nVallam,                            7',
#  '7\nRevenue\nThanjavur\nThirukkattupalli,                            3.2',
#  '8\nRevenue\nThanjavur\nAyyampettai,                            3',
#  '9\nRevenue\nThanjavur\nThiruvidaimaruthur,                            2.2',
#  '10\nRevenue\nThanjavur\nPapanasam,                            2',
#  '11\nRevenue\nThanjavur\nManjalaru,                            1.8',
#  '12\nRevenue\nThanjavur\nLower Anaicut,                            1.4',
#  '13\nRevenue\nThanjavur\nEchanviduthi,                            1.2',
#  '14\nRevenue\nThanjavur\nTaluk Office, Kumbakonam,                            1.2',
#  '15\nRevenue\nThanjavur\nThiruvaiyaru,                            1',
#  '16\nRevenue\nThanjavur\nPattukkottai,                            1',
#  '17\nRevenue\nThanjavur\nGrand Anaicut,                            0.6',
#  '18\nRevenue\nThanjavur\nThanjavur,                            0.5',
#  '19\nRevenue\nThanjavur\nAdirampatnam,                            0.4',
#  'Total rainfall\n117.7',
#  'Average rainfall\n5.6',
#  '1\nRevenue\nThiruchirappalli\nThenparanadu,                            14',
#  '2\nRevenue\nThiruchirappalli\nTiruchirappalli Town,                            3',
#  '3\nRevenue\nThiruchirappalli\nThuvakudi,                            1',
#  '4\nRevenue\nThiruchirappalli\nTiruchirappalli Junction,                            0.6',
#  '5\nRevenue\nThiruchirappalli\nTiruchirappalli Airport,                            0.4',
#  'Total rainfall\n19',
#  'Average rainfall\n0.79',
#  '1\nRevenue\nThiruvarur\nNeedamangalam,                            35.4',
#  '2\nRevenue\nThiruvarur\nMannargudi,                            32',
#  '3\nRevenue\nThiruvarur\nTaluk Office , Tiruvarur,                            31',
#  '4\nRevenue\nThiruvarur\nKudavasal,                            19.4',
#  '5\nRevenue\nThiruvarur\nTaluk Office, Nannilam,                            14.2',
#  '6\nRevenue\nThiruvarur\nPandavaiyaru,                            12.4',
#  '7\nRevenue\nThiruvarur\nTaluk Office, Thiruthuraipoondi,                            10.4',
#  '8\nRevenue\nThiruvarur\nSub Registrar Office, Muthupettai,                            3.2',
#  'Total rainfall\n158',
#  'Average rainfall\n17.56',
#  '1\nRevenue\nTirunelveli\nOothu,                            34',
#  '2\nRevenue\nTirunelveli\nNalumukku,                            30',
#  '3\nRevenue\nTirunelveli\nKakkachi,                            21',
#  '4\nRevenue\nTirunelveli\nManjolai,                            14',
#  '5\nRevenue\nTirunelveli\nPapanasam,                            4',
#  '6\nRevenue\nTirunelveli\nKannadian Anicut,                            3.4',
#  '7\nRevenue\nTirunelveli\nAmbasamudram,                            2.8',
#  '8\nRevenue\nTirunelveli\nCheranmahadevi,                            1.4',
#  '9\nRevenue\nTirunelveli\nManimutharu,                            1.2',
#  '10\nRevenue\nTirunelveli\nKalakadu,                            1',
#  'Total rainfall\n112.8',
#  'Average rainfall\n6.27',
#  '1\nRevenue\nTiruppur\nUdumalpet,                            1',
#  '2\nRevenue\nTiruppur\nMadathukulam,                            1',
#  'Total rainfall\n2',
#  'Average rainfall\n0.1',
#  '1\nRevenue\nTiruvannamalai\nKilpennathur,                            5',
#  '2\nRevenue\nTiruvannamalai\nVembakkam,                            2',
#  'Total rainfall\n7',
#  'Average rainfall\n0.58',
#  '1\nRevenue\nVillupuram\nRSCL-2 Valavanur,                            12',
#  '2\nRevenue\nVillupuram\nVILUPPURAM,                            10',
#  '3\nRevenue\nVillupuram\nRSCL-2 Koliyanur,                            10',
#  '4\nRevenue\nVillupuram\nTINDIVANAM,                            5',
#  '5\nRevenue\nVillupuram\nRSCL-3 Semmedu,                            4.4',
#  '6\nRevenue\nVillupuram\nRSCL-2 Soorapattu,                            3',
#  '7\nRevenue\nVillupuram\nMarakkanam,                            3',
#  '8\nRevenue\nVillupuram\nVANUR,                            2',
#  '9\nRevenue\nVillupuram\nRSCL-2 Mundiyampakkam,                            2',
#  '10\nRevenue\nVillupuram\nRSCL-2 Kedar,                            2',
#  '11\nRevenue\nVillupuram\nGingee,                            2',
#  '12\nRevenue\nVillupuram\nRSCL-3 Avalurpettai,                            2',
#  '13\nRevenue\nVillupuram\nSCS MILL Arasoor,                            2',
#  '14\nRevenue\nVillupuram\nSCS MILL Thiruvennainallur,                            2',
#  '15\nRevenue\nVillupuram\nRSCL-2 Kanjanur,                            1',
#  '16\nRevenue\nVillupuram\nRSCL-3 Valathy,                            1',
#  'Total rainfall\n63.4',
#  'Average rainfall\n3.02',
#  'No\n                                rain\nVery\n                                light rain\nLight rain\nModerate rain\nHeavy rain\nVery\n                                heavy rain\nExtreme heavy rain']

# %%
datalist = []
datalist
# Out:
# []

# %%
list[0].strip().replace("\n",",")
# Out:
# '1,Revenue,Ariyalur,Suthamalli dam,                            5'

# %%
range(len(list))
# Out:
# range(0, 203)

# %%
for i in range(len(list)):
    datalist.append(list[i].strip().replace("\n",","))

# %%
# List of all data
datalist
# Out:
# ['1,Revenue,Ariyalur,Suthamalli dam,                            5',
#  '2,Revenue,Ariyalur,Kuruvadi,                            4',
#  '3,Revenue,Ariyalur,Jayankondam taluk office,                            4',
#  '4,Revenue,Ariyalur,PWD Office, Sendurai,                            3.6',
#  '5,Revenue,Ariyalur,Taluk Office, Andimadam,                            3',
#  '6,Revenue,Ariyalur,Ariyalur Taluk Office,                            2.5',
#  '7,Revenue,Ariyalur,THIRUMANUR  PWD OFFICE (R.C.DIVISION),                            2',
#  '8,Revenue,Ariyalur,T.Palur Panchayat Union 0ffice,                            1',
#  'Total rainfall,25.1',
#  'Average rainfall,3.14',
#  '1,Revenue,Chengalpattu,Taluk Office, Thirukalukundram,                            45',
#  '2,Revenue,Chengalpattu,Mammallapuram PWD bungalow,                            38',
#  '3,Revenue,Chengalpattu,Keelampakkam,                            14.2',
#  '4,Revenue,Chengalpattu,Taluk Office, Thiruporur,                            10',
#  '5,Revenue,Chengalpattu,Chengalpattu,                            5',
#  '6,Revenue,Chengalpattu,Madurantakam taluk office,                            4',
#  '7,Revenue,Chengalpattu,Taluk Office, Tambaram,                            2',
#  '8,CMWSSB,Chengalpattu,Alandur,                            2',
#  'Total rainfall,120.2',
#  'Average rainfall,13.36',
#  '1,GCC,Chennai,Zone 15 Uthandi,                            15.6',
#  '2,GCC,Chennai,Zone 15 Sholinganallur,                            5.6',
#  '3,GCC,Chennai,Zone 12 Meenambakkam,                            3.6',
#  '4,GCC,Chennai,Zone 12 Alandhur,                            3.3',
#  '5,Revenue,Chennai,Sholinganallur,                            3',
#  '6,GCC,Chennai,Zone 09 Ice House,                            3',
#  '7,Revenue,Chennai,Alandur,                            2.9',
#  '8,GCC,Chennai,Zone 13 Raja Annamalai puram,                            2.4',
#  '9,GCC,Chennai,Zone 14 Perungudi,                            2.4',
#  '10,CMWSSB,Chennai,Sholinganallur,                            2.2',
#  '11,Revenue,Chennai,Anna university,                            1.8',
#  '12,GCC,Chennai,Zone 13 Adyar,                            1.8',
#  '13,GCC,Chennai,Zone 14 Madipakkam,                            1.5',
#  '14,GCC,Chennai,Zone 13 Velachery,                            1.2',
#  '15,CMWSSB,Chennai,Perungudi,                            1',
#  '16,CMWSSB,Chennai,Adyar,                            0.4',
#  'Total rainfall,51.7',
#  'Average rainfall,0.94',
#  '1,Revenue,Cuddalore,Vanamadevi,                            15.6',
#  '2,Revenue,Cuddalore,Panruti,                            15',
#  '3,Revenue,Cuddalore,Pelandurai,                            13.6',
#  '4,Revenue,Cuddalore,Kurinjipadi,                            10',
#  '5,Revenue,Cuddalore,SRC Kudithangi,                            9',
#  '6,Revenue,Cuddalore,Srimushnam,                            8.2',
#  '7,Revenue,Cuddalore,Veppur,                            8',
#  '8,Revenue,Cuddalore,Vadakuthu,                            8',
#  '9,Revenue,Cuddalore,Vridhachalam,                            7',
#  '10,Revenue,Cuddalore,Tozhudur,                            6',
#  '11,Revenue,Cuddalore,Indian Metrology Department,                            5.8',
#  '12,Revenue,Cuddalore,Kattumayilur,                            5',
#  '13,Revenue,Cuddalore,Kuppanatham,                            5',
#  '14,Revenue,Cuddalore,Collectorate,                            4.9',
#  '15,Revenue,Cuddalore,Kilacheruvai,                            4',
#  '16,Revenue,Cuddalore,Sethiyathope,                            3.2',
#  '17,Revenue,Cuddalore,Me.Mathur,                            3',
#  '18,Revenue,Cuddalore,Kothavacherry,                            2',
#  '19,Revenue,Cuddalore,Lalpet,                            2',
#  '20,Revenue,Cuddalore,Annamalai Nagar,                            1.5',
#  '21,Revenue,Cuddalore,Kattumannarkoil,                            1.4',
#  '22,Revenue,Cuddalore,Parangipettai,                            1',
#  '23,Revenue,Cuddalore,Chidambaram,                            1',
#  'Total rainfall,140.2',
#  'Average rainfall,5.61',
#  '1,Revenue,Dindigul,Palani,                            1',
#  '2,Revenue,Dindigul,Kamatchipuram,                            0.8',
#  '3,Revenue,Dindigul,VEDASANDUR,                            0.6',
#  '4,Revenue,Dindigul,TOBACCO STATION(VDR),                            0.6',
#  'Total rainfall,3',
#  'Average rainfall,0.3',
#  '1,Revenue,Kancheepuram,Sriperumbadur,                            2',
#  '2,Revenue,Kancheepuram,Kancheepuram taluk office,                            1',
#  'Total rainfall,3',
#  'Average rainfall,0.5',
#  '1,Revenue,Madurai,Elumalai,                            0.4',
#  'Total rainfall,0.4',
#  'Average rainfall,0.02',
#  '1,Revenue,Mayiladuthurai,Mayiladuthurai,                            4.2',
#  '2,Revenue,Mayiladuthurai,Sirkali,                            2.6',
#  '3,Revenue,Mayiladuthurai,Sembanarkoil (PWD),                            1.4',
#  'Total rainfall,8.2',
#  'Average rainfall,1.37',
#  '1,Revenue,Nagapattinam,Nagapattinam,                            81.4',
#  '2,Revenue,Nagapattinam,Velankanni,                            72.6',
#  '3,Revenue,Nagapattinam,Thirupoondi,                            13.2',
#  '4,Revenue,Nagapattinam,Kodiayakarai,                            10.8',
#  '5,Revenue,Nagapattinam,Vedaranyam,                            9.5',
#  '6,Revenue,Nagapattinam,Thirukuvalai,                            7',
#  '7,Revenue,Nagapattinam,Thalanayar,                            4',
#  'Total rainfall,198.5',
#  'Average rainfall,28.36',
#  '1,Revenue,Perambalur,Puthu vettakudi,                            8',
#  '2,Revenue,Perambalur,Labbaikudikadu,                            3',
#  '3,Revenue,Perambalur,Agaram seegoor,                            3',
#  '4,Revenue,Perambalur,Eraiyur,                            3',
#  '5,Revenue,Perambalur,VEPPANTHATTAI,                            2',
#  '6,Revenue,Perambalur,V.KALATHUR,                            2',
#  '7,Revenue,Perambalur,Chettikulam,                            1',
#  '8,Revenue,Perambalur,Perambalur,                            1',
#  'Total rainfall,23',
#  'Average rainfall,2.09',
#  '1,Revenue,Pudukkottai,Gandarvakottai,                            8',
#  '2,Revenue,Pudukkottai,Karaiyur,                            5.2',
#  '3,Revenue,Pudukkottai,Perungalur,                            5',
#  '4,Revenue,Pudukkottai,Malaiyur,                            4.6',
#  '5,Revenue,Pudukkottai,Alangudi,                            4.6',
#  '6,Revenue,Pudukkottai,Pudukkottai,                            4.5',
#  '7,Revenue,Pudukkottai,Karambakudi,                            4',
#  '8,Revenue,Pudukkottai,Kudimiyanmalai,                            4',
#  '9,Revenue,Pudukkottai,THIRUMAYAM,                            2',
#  '10,Revenue,Pudukkottai,Manamelkudi,                            2',
#  '11,Revenue,Pudukkottai,Annavasal,                            2',
#  '12,Revenue,Pudukkottai,Keeranur,                            1.6',
#  'Total rainfall,47.5',
#  'Average rainfall,1.98',
#  '1,Revenue,Ramanathapuram,Mandapam,                            1.1',
#  '2,Revenue,Ramanathapuram,pamban,                            1',
#  '3,Revenue,Ramanathapuram,Thangachimadam,                            1',
#  '4,Revenue,Ramanathapuram,Rameswaram,                            0.8',
#  'Total rainfall,3.9',
#  'Average rainfall,0.24',
#  '1,Revenue,Salem,Yercaud,                            1',
#  'Total rainfall,1',
#  'Average rainfall,0.06',
#  '1,Revenue,Sivagangai,Thiruppathur,                            2',
#  'Total rainfall,2',
#  'Average rainfall,0.22',
#  '1,Revenue,Thanjavur,Orathanad,                            25',
#  '2,Revenue,Thanjavur,Neivasal Thenpathi,                            20',
#  '3,Revenue,Thanjavur,Vettikadu,                            19.6',
#  '4,Revenue,Thanjavur,Madukkur,                            15.6',
#  '5,Revenue,Thanjavur,Kurungulam,                            11',
#  '6,Revenue,Thanjavur,Vallam,                            7',
#  '7,Revenue,Thanjavur,Thirukkattupalli,                            3.2',
#  '8,Revenue,Thanjavur,Ayyampettai,                            3',
#  '9,Revenue,Thanjavur,Thiruvidaimaruthur,                            2.2',
#  '10,Revenue,Thanjavur,Papanasam,                            2',
#  '11,Revenue,Thanjavur,Manjalaru,                            1.8',
#  '12,Revenue,Thanjavur,Lower Anaicut,                            1.4',
#  '13,Revenue,Thanjavur,Echanviduthi,                            1.2',
#  '14,Revenue,Thanjavur,Taluk Office, Kumbakonam,                            1.2',
#  '15,Revenue,Thanjavur,Thiruvaiyaru,                            1',
#  '16,Revenue,Thanjavur,Pattukkottai,                            1',
#  '17,Revenue,Thanjavur,Grand Anaicut,                            0.6',
#  '18,Revenue,Thanjavur,Thanjavur,                            0.5',
#  '19,Revenue,Thanjavur,Adirampatnam,                            0.4',
#  'Total rainfall,117.7',
#  'Average rainfall,5.6',
#  '1,Revenue,Thiruchirappalli,Thenparanadu,                            14',
#  '2,Revenue,Thiruchirappalli,Tiruchirappalli Town,                            3',
#  '3,Revenue,Thiruchirappalli,Thuvakudi,                            1',
#  '4,Revenue,Thiruchirappalli,Tiruchirappalli Junction,                            0.6',
#  '5,Revenue,Thiruchirappalli,Tiruchirappalli Airport,                            0.4',
#  'Total rainfall,19',
#  'Average rainfall,0.79',
#  '1,Revenue,Thiruvarur,Needamangalam,                            35.4',
#  '2,Revenue,Thiruvarur,Mannargudi,                            32',
#  '3,Revenue,Thiruvarur,Taluk Office , Tiruvarur,                            31',
#  '4,Revenue,Thiruvarur,Kudavasal,                            19.4',
#  '5,Revenue,Thiruvarur,Taluk Office, Nannilam,                            14.2',
#  '6,Revenue,Thiruvarur,Pandavaiyaru,                            12.4',
#  '7,Revenue,Thiruvarur,Taluk Office, Thiruthuraipoondi,                            10.4',
#  '8,Revenue,Thiruvarur,Sub Registrar Office, Muthupettai,                            3.2',
#  'Total rainfall,158',
#  'Average rainfall,17.56',
#  '1,Revenue,Tirunelveli,Oothu,                            34',
#  '2,Revenue,Tirunelveli,Nalumukku,                            30',
#  '3,Revenue,Tirunelveli,Kakkachi,                            21',
#  '4,Revenue,Tirunelveli,Manjolai,                            14',
#  '5,Revenue,Tirunelveli,Papanasam,                            4',
#  '6,Revenue,Tirunelveli,Kannadian Anicut,                            3.4',
#  '7,Revenue,Tirunelveli,Ambasamudram,                            2.8',
#  '8,Revenue,Tirunelveli,Cheranmahadevi,                            1.4',
#  '9,Revenue,Tirunelveli,Manimutharu,                            1.2',
#  '10,Revenue,Tirunelveli,Kalakadu,                            1',
#  'Total rainfall,112.8',
#  'Average rainfall,6.27',
#  '1,Revenue,Tiruppur,Udumalpet,                            1',
#  '2,Revenue,Tiruppur,Madathukulam,                            1',
#  'Total rainfall,2',
#  'Average rainfall,0.1',
#  '1,Revenue,Tiruvannamalai,Kilpennathur,                            5',
#  '2,Revenue,Tiruvannamalai,Vembakkam,                            2',
#  'Total rainfall,7',
#  'Average rainfall,0.58',
#  '1,Revenue,Villupuram,RSCL-2 Valavanur,                            12',
#  '2,Revenue,Villupuram,VILUPPURAM,                            10',
#  '3,Revenue,Villupuram,RSCL-2 Koliyanur,                            10',
#  '4,Revenue,Villupuram,TINDIVANAM,                            5',
#  '5,Revenue,Villupuram,RSCL-3 Semmedu,                            4.4',
#  '6,Revenue,Villupuram,RSCL-2 Soorapattu,                            3',
#  '7,Revenue,Villupuram,Marakkanam,                            3',
#  '8,Revenue,Villupuram,VANUR,                            2',
#  '9,Revenue,Villupuram,RSCL-2 Mundiyampakkam,                            2',
#  '10,Revenue,Villupuram,RSCL-2 Kedar,                            2',
#  '11,Revenue,Villupuram,Gingee,                            2',
#  '12,Revenue,Villupuram,RSCL-3 Avalurpettai,                            2',
#  '13,Revenue,Villupuram,SCS MILL Arasoor,                            2',
#  '14,Revenue,Villupuram,SCS MILL Thiruvennainallur,                            2',
#  '15,Revenue,Villupuram,RSCL-2 Kanjanur,                            1',
#  '16,Revenue,Villupuram,RSCL-3 Valathy,                            1',
#  'Total rainfall,63.4',
#  'Average rainfall,3.02',
#  'No,                                rain,Very,                                light rain,Light rain,Moderate rain,Heavy rain,Very,                                heavy rain,Extreme heavy rain']

# %%
#Make DataFrame for further data wrangling
df = pd.DataFrame(datalist, columns = ['A'])

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#                                                      A
# 0    1,Revenue,Ariyalur,Suthamalli dam,            ...
# 1    2,Revenue,Ariyalur,Kuruvadi,                  ...
# 2    3,Revenue,Ariyalur,Jayankondam taluk office,  ...
# 3    4,Revenue,Ariyalur,PWD Office, Sendurai,      ...
# 4    5,Revenue,Ariyalur,Taluk Office, Andimadam,   ...
# ..                                                 ...
# 198  15,Revenue,Villupuram,RSCL-2 Kanjanur,        ...
# 199  16,Revenue,Villupuram,RSCL-3 Valathy,         ...
# 200                                Total rainfall,63.4
# 201                              Average rainfall,3.02
# 202  No,                                rain,Very, ...
#
# [203 rows x 1 columns]

# %%
# Split the Data into columns
df1 = df1.A.str.split(",",expand = True)
df1
# Out:
#                     0                                     1           2  \
# 0                   1                               Revenue    Ariyalur
# 1                   2                               Revenue    Ariyalur
# 2                   3                               Revenue    Ariyalur
# 3                   4                               Revenue    Ariyalur
# 4                   5                               Revenue    Ariyalur
# ..                ...                                   ...         ...
# 198                15                               Revenue  Villupuram
# 199                16                               Revenue  Villupuram
# 200    Total rainfall                                  63.4        None
# 201  Average rainfall                                  3.02        None
# 202                No                                  rain        Very
#
#                                               3  \
# 0                                Suthamalli dam
# 1                                      Kuruvadi
# 2                      Jayankondam taluk office
# 3                                    PWD Office
# 4                                  Taluk Office
# ..                                          ...
# 198                             RSCL-2 Kanjanur
# 199                              RSCL-3 Valathy
# 200                                        None
# 201                                        None
# 202                                  light rain
#
#                                  4                                5  \
# 0                                5                             None
# 1                                4                             None
# 2                                4                             None
# 3                         Sendurai                              3.6
# 4                        Andimadam                                3
# ..                             ...                              ...
# 198                              1                             None
# 199                              1                             None
# 200                           None                             None
# 201                           None                             None
# 202                     Light rain                    Moderate rain
#
#               6     7                                           8  \
# 0          None  None                                        None
# 1          None  None                                        None
# 2          None  None                                        None
# 3          None  None                                        None
# 4          None  None                                        None
# ..          ...   ...                                         ...
# 198        None  None                                        None
# 199        None  None                                        None
# 200        None  None                                        None
# 201        None  None                                        None
# 202  Heavy rain  Very                                  heavy rain
#
#                       9
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# ..                  ...
# 198                None
# 199                None
# 200                None
# 201                None
# 202  Extreme heavy rain
#
# [203 rows x 10 columns]

# %%
df1.isna().sum()
# Out:
# 0      0
# 1      0
# 2     42
# 3     42
# 4     42
# 5    192
# 6    202
# 7    202
# 8    202
# 9    202
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       203 non-null    object
#  1   1       203 non-null    object
#  2   2       161 non-null    object
#  3   3       161 non-null    object
#  4   4       161 non-null    object
#  5   5       11 non-null     object
#  6   6       1 non-null      object
#  7   7       1 non-null      object
#  8   8       1 non-null      object
#  9   9       1 non-null      object
# dtypes: object(10)
# memory usage: 16.0+ KB

# %%
df1 = df1.drop(columns = [6,7,8,9])
df1
# Out:
#                     0                                     1           2  \
# 0                   1                               Revenue    Ariyalur
# 1                   2                               Revenue    Ariyalur
# 2                   3                               Revenue    Ariyalur
# 3                   4                               Revenue    Ariyalur
# 4                   5                               Revenue    Ariyalur
# ..                ...                                   ...         ...
# 198                15                               Revenue  Villupuram
# 199                16                               Revenue  Villupuram
# 200    Total rainfall                                  63.4        None
# 201  Average rainfall                                  3.02        None
# 202                No                                  rain        Very
#
#                                               3  \
# 0                                Suthamalli dam
# 1                                      Kuruvadi
# 2                      Jayankondam taluk office
# 3                                    PWD Office
# 4                                  Taluk Office
# ..                                          ...
# 198                             RSCL-2 Kanjanur
# 199                              RSCL-3 Valathy
# 200                                        None
# 201                                        None
# 202                                  light rain
#
#                                  4                                5
# 0                                5                             None
# 1                                4                             None
# 2                                4                             None
# 3                         Sendurai                              3.6
# 4                        Andimadam                                3
# ..                             ...                              ...
# 198                              1                             None
# 199                              1                             None
# 200                           None                             None
# 201                           None                             None
# 202                     Light rain                    Moderate rain
#
# [203 rows x 6 columns]

# %%
# Unwanted rows
df1[df1[4].isna()]
# Out:
#                     0      1     2     3     4     5
# 8      Total rainfall   25.1  None  None  None  None
# 9    Average rainfall   3.14  None  None  None  None
# 18     Total rainfall  120.2  None  None  None  None
# 19   Average rainfall  13.36  None  None  None  None
# 36     Total rainfall   51.7  None  None  None  None
# 37   Average rainfall   0.94  None  None  None  None
# 61     Total rainfall  140.2  None  None  None  None
# 62   Average rainfall   5.61  None  None  None  None
# 67     Total rainfall      3  None  None  None  None
# 68   Average rainfall    0.3  None  None  None  None
# 71     Total rainfall      3  None  None  None  None
# 72   Average rainfall    0.5  None  None  None  None
# 74     Total rainfall    0.4  None  None  None  None
# 75   Average rainfall   0.02  None  None  None  None
# 79     Total rainfall    8.2  None  None  None  None
# 80   Average rainfall   1.37  None  None  None  None
# 88     Total rainfall  198.5  None  None  None  None
# 89   Average rainfall  28.36  None  None  None  None
# 98     Total rainfall     23  None  None  None  None
# 99   Average rainfall   2.09  None  None  None  None
# 112    Total rainfall   47.5  None  None  None  None
# 113  Average rainfall   1.98  None  None  None  None
# 118    Total rainfall    3.9  None  None  None  None
# 119  Average rainfall   0.24  None  None  None  None
# 121    Total rainfall      1  None  None  None  None
# 122  Average rainfall   0.06  None  None  None  None
# 124    Total rainfall      2  None  None  None  None
# 125  Average rainfall   0.22  None  None  None  None
# 145    Total rainfall  117.7  None  None  None  None
# 146  Average rainfall    5.6  None  None  None  None
# 152    Total rainfall     19  None  None  None  None
# 153  Average rainfall   0.79  None  None  None  None
# 162    Total rainfall    158  None  None  None  None
# 163  Average rainfall  17.56  None  None  None  None
# 174    Total rainfall  112.8  None  None  None  None
# 175  Average rainfall   6.27  None  None  None  None
# 178    Total rainfall      2  None  None  None  None
# 179  Average rainfall    0.1  None  None  None  None
# 182    Total rainfall      7  None  None  None  None
# 183  Average rainfall   0.58  None  None  None  None
# 200    Total rainfall   63.4  None  None  None  None
# 201  Average rainfall   3.02  None  None  None  None

# %%
# Unwanted row list
delete_rows = df1[df1[4].isna()].index
delete_rows
# Out:
# Index([  8,   9,  18,  19,  36,  37,  61,  62,  67,  68,  71,  72,  74,  75,
#         79,  80,  88,  89,  98,  99, 112, 113, 118, 119, 121, 122, 124, 125,
#        145, 146, 152, 153, 162, 163, 174, 175, 178, 179, 182, 183, 200, 201],
#       dtype='int64')

# %%
# The unwanted unwanted row add into the delete_rows list
delete_rows = delete_rows.append(df1[-1:].index)

# %%
delete_rows
# Out:
# Index([  8,   9,  18,  19,  36,  37,  61,  62,  67,  68,  71,  72,  74,  75,
#         79,  80,  88,  89,  98,  99, 112, 113, 118, 119, 121, 122, 124, 125,
#        145, 146, 152, 153, 162, 163, 174, 175, 178, 179, 182, 183, 200, 201,
#        202],
#       dtype='int64')

# %%
# delete the rows 
df1 = df1.drop(delete_rows,axis=0)

# %%
df1
# Out:
#       0        1           2                           3  \
# 0     1  Revenue    Ariyalur              Suthamalli dam
# 1     2  Revenue    Ariyalur                    Kuruvadi
# 2     3  Revenue    Ariyalur    Jayankondam taluk office
# 3     4  Revenue    Ariyalur                  PWD Office
# 4     5  Revenue    Ariyalur                Taluk Office
# ..   ..      ...         ...                         ...
# 195  12  Revenue  Villupuram         RSCL-3 Avalurpettai
# 196  13  Revenue  Villupuram            SCS MILL Arasoor
# 197  14  Revenue  Villupuram  SCS MILL Thiruvennainallur
# 198  15  Revenue  Villupuram             RSCL-2 Kanjanur
# 199  16  Revenue  Villupuram              RSCL-3 Valathy
#
#                                  4                                5
# 0                                5                             None
# 1                                4                             None
# 2                                4                             None
# 3                         Sendurai                              3.6
# 4                        Andimadam                                3
# ..                             ...                              ...
# 195                              2                             None
# 196                              2                             None
# 197                              2                             None
# 198                              1                             None
# 199                              1                             None
#
# [160 rows x 6 columns]

# %%
# Retrive text from colum no 4
df1[4.1] = df1[4].str.extract('([a-zA-Z]+)')

# %%
df1
# Out:
#     0.0      1.0         2.0                         3.0  \
# 0     1  Revenue    Ariyalur              Suthamalli dam
# 1     2  Revenue    Ariyalur                    Kuruvadi
# 2     3  Revenue    Ariyalur    Jayankondam taluk office
# 3     4  Revenue    Ariyalur                  PWD Office
# 4     5  Revenue    Ariyalur                Taluk Office
# ..   ..      ...         ...                         ...
# 195  12  Revenue  Villupuram         RSCL-3 Avalurpettai
# 196  13  Revenue  Villupuram            SCS MILL Arasoor
# 197  14  Revenue  Villupuram  SCS MILL Thiruvennainallur
# 198  15  Revenue  Villupuram             RSCL-2 Kanjanur
# 199  16  Revenue  Villupuram              RSCL-3 Valathy
#
#                                4.0                              5.0        4.1
# 0                                5                             None        NaN
# 1                                4                             None        NaN
# 2                                4                             None        NaN
# 3                         Sendurai                              3.6   Sendurai
# 4                        Andimadam                                3  Andimadam
# ..                             ...                              ...        ...
# 195                              2                             None        NaN
# 196                              2                             None        NaN
# 197                              2                             None        NaN
# 198                              1                             None        NaN
# 199                              1                             None        NaN
#
# [160 rows x 7 columns]

# %% [markdown]
# #### Combine columns 4.0 and 4.1 to create a valid location. using loc method

# %%
df1[4.1].dropna()
# Out:
# 3               Sendurai
# 4              Andimadam
# 10      Thirukalukundram
# 13            Thiruporur
# 16              Tambaram
# 139           Kumbakonam
# 156            Tiruvarur
# 158             Nannilam
# 160    Thiruthuraipoondi
# 161          Muthupettai
# Name: 4.1, dtype: object

# %%
df1[4.1].dropna().index
# Out:
# Index([3, 4, 10, 13, 16, 139, 156, 158, 160, 161], dtype='int64')

# %%
df1[4.1].dropna().values
# Out:
# array(['Sendurai', 'Andimadam', 'Thirukalukundram', 'Thiruporur',
#        'Tambaram', 'Kumbakonam', 'Tiruvarur', 'Nannilam',
#        'Thiruthuraipoondi', 'Muthupettai'], dtype=object)

# %%
df1[3].loc[df1[4.1].dropna().index] = df1[3].loc[df1[4.1].dropna().index] + "," + df1[4.1].dropna().values
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_14532\2473872667.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df1[3].loc[df1[4.1].dropna().index] = df1[3].loc[df1[4.1].dropna().index] + "," + df1[4.1].dropna().values

# %%
df1
# Out:
#     0.0      1.0         2.0                         3.0  \
# 0     1  Revenue    Ariyalur              Suthamalli dam
# 1     2  Revenue    Ariyalur                    Kuruvadi
# 2     3  Revenue    Ariyalur    Jayankondam taluk office
# 3     4  Revenue    Ariyalur         PWD Office,Sendurai
# 4     5  Revenue    Ariyalur      Taluk Office,Andimadam
# ..   ..      ...         ...                         ...
# 195  12  Revenue  Villupuram         RSCL-3 Avalurpettai
# 196  13  Revenue  Villupuram            SCS MILL Arasoor
# 197  14  Revenue  Villupuram  SCS MILL Thiruvennainallur
# 198  15  Revenue  Villupuram             RSCL-2 Kanjanur
# 199  16  Revenue  Villupuram              RSCL-3 Valathy
#
#                                4.0                              5.0        4.1
# 0                                5                             None        NaN
# 1                                4                             None        NaN
# 2                                4                             None        NaN
# 3                         Sendurai                              3.6   Sendurai
# 4                        Andimadam                                3  Andimadam
# ..                             ...                              ...        ...
# 195                              2                             None        NaN
# 196                              2                             None        NaN
# 197                              2                             None        NaN
# 198                              1                             None        NaN
# 199                              1                             None        NaN
#
# [160 rows x 7 columns]

# %% [markdown]
# #### Combine the floating point values from columns 4.0 and 5.0 into a single column, ensuring that non-numeric data is properly handled.

# %%
df1[4].loc[df1[4.1].dropna().index]
# Out:
# 3                Sendurai
# 4               Andimadam
# 10       Thirukalukundram
# 13             Thiruporur
# 16               Tambaram
# 139            Kumbakonam
# 156             Tiruvarur
# 158              Nannilam
# 160     Thiruthuraipoondi
# 161           Muthupettai
# Name: 4, dtype: object

# %%
df1[5].loc[df1[4.1].dropna().index]
# Out:
# 3                                   3.6
# 4                                     3
# 10                                   45
# 13                                   10
# 16                                    2
# 139                                 1.2
# 156                                  31
# 158                                14.2
# 160                                10.4
# 161                                 3.2
# Name: 5.0, dtype: object

# %%
df1[4].loc[df1[4.1].dropna().index] = df1[5].loc[df1[4.1].dropna().index]

# %%
df1
# Out:
#     0.0      1.0         2.0                         3.0  \
# 0     1  Revenue    Ariyalur              Suthamalli dam
# 1     2  Revenue    Ariyalur                    Kuruvadi
# 2     3  Revenue    Ariyalur    Jayankondam taluk office
# 3     4  Revenue    Ariyalur         PWD Office,Sendurai
# 4     5  Revenue    Ariyalur      Taluk Office,Andimadam
# ..   ..      ...         ...                         ...
# 195  12  Revenue  Villupuram         RSCL-3 Avalurpettai
# 196  13  Revenue  Villupuram            SCS MILL Arasoor
# 197  14  Revenue  Villupuram  SCS MILL Thiruvennainallur
# 198  15  Revenue  Villupuram             RSCL-2 Kanjanur
# 199  16  Revenue  Villupuram              RSCL-3 Valathy
#
#                                  4.0                              5.0  \
# 0                                  5                             None
# 1                                  4                             None
# 2                                  4                             None
# 3                                3.6                              3.6
# 4                                  3                                3
# ..                               ...                              ...
# 195                                2                             None
# 196                                2                             None
# 197                                2                             None
# 198                                1                             None
# 199                                1                             None
#
#            4.1
# 0          NaN
# 1          NaN
# 2          NaN
# 3     Sendurai
# 4    Andimadam
# ..         ...
# 195        NaN
# 196        NaN
# 197        NaN
# 198        NaN
# 199        NaN
#
# [160 rows x 7 columns]

# %%
# Drop the unwanted columns to clean up the dataset.
df1 = df1.drop(columns = [0.0,5.0,4.1])

# %%
df1
# Out:
#          1.0         2.0                         3.0  \
# 0    Revenue    Ariyalur              Suthamalli dam
# 1    Revenue    Ariyalur                    Kuruvadi
# 2    Revenue    Ariyalur    Jayankondam taluk office
# 3    Revenue    Ariyalur         PWD Office,Sendurai
# 4    Revenue    Ariyalur      Taluk Office,Andimadam
# ..       ...         ...                         ...
# 195  Revenue  Villupuram         RSCL-3 Avalurpettai
# 196  Revenue  Villupuram            SCS MILL Arasoor
# 197  Revenue  Villupuram  SCS MILL Thiruvennainallur
# 198  Revenue  Villupuram             RSCL-2 Kanjanur
# 199  Revenue  Villupuram              RSCL-3 Valathy
#
#                                  4.0
# 0                                  5
# 1                                  4
# 2                                  4
# 3                                3.6
# 4                                  3
# ..                               ...
# 195                                2
# 196                                2
# 197                                2
# 198                                1
# 199                                1
#
# [160 rows x 4 columns]

# %%
df1.columns
# Out:
# Index([1.0, 2.0, 3.0, 4.0], dtype='float64')

# %%
table_title
# Out:
# ['வரிசை எண்',
#  'உரிமையாளர்',
#  'மாவட்டம்',
#  'மழைமானி நிலையம்',
#  'பதிவான மழை அளவு (மி.மீ.)']

# %%
# Assign appropriate column titles to the dataset for better clarity and organization.
column_Name = ['dept', 'dist', 'station', 'value']

# %%
df1.columns = column_Name

# %%
df1
# Out:
#         dept        dist                     station  \
# 0    Revenue    Ariyalur              Suthamalli dam
# 1    Revenue    Ariyalur                    Kuruvadi
# 2    Revenue    Ariyalur    Jayankondam taluk office
# 3    Revenue    Ariyalur         PWD Office,Sendurai
# 4    Revenue    Ariyalur      Taluk Office,Andimadam
# ..       ...         ...                         ...
# 195  Revenue  Villupuram         RSCL-3 Avalurpettai
# 196  Revenue  Villupuram            SCS MILL Arasoor
# 197  Revenue  Villupuram  SCS MILL Thiruvennainallur
# 198  Revenue  Villupuram             RSCL-2 Kanjanur
# 199  Revenue  Villupuram              RSCL-3 Valathy
#
#                                value
# 0                                  5
# 1                                  4
# 2                                  4
# 3                                3.6
# 4                                  3
# ..                               ...
# 195                                2
# 196                                2
# 197                                2
# 198                                1
# 199                                1
#
# [160 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dept     160 non-null    object
#  1   dist     160 non-null    object
#  2   station  160 non-null    object
#  3   value    160 non-null    object
# dtypes: object(4)
# memory usage: 10.3+ KB

# %%
df1.value = df1.value.astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dept     160 non-null    object
#  1   dist     160 non-null    object
#  2   station  160 non-null    object
#  3   value    160 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 10.3+ KB

# %%
# Reset the index and drop the old index to ensure a clean and sequential dataset.
df1 = df1.reset_index()

# %%
df1 = df1.drop(columns = 'index')

# %% [markdown]
# ### Form a DataFrame using the current date as the data for processing.

# %%
len(df1)
# Out:
# 160

# %%
# create DF to feed into the rainfall data 
DL = [Da] 
for i in range (len(df1)):
    DL.append(DL[0])

# %%
DL
# Out:
# ['30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024',
#  '30-12-2024']

# %%
C_Date = pd.DataFrame(DL,columns= ['date'])

# %%
C_Date.date
# Out:
# 0      30-12-2024
# 1      30-12-2024
# 2      30-12-2024
# 3      30-12-2024
# 4      30-12-2024
#           ...
# 156    30-12-2024
# 157    30-12-2024
# 158    30-12-2024
# 159    30-12-2024
# 160    30-12-2024
# Name: date, Length: 161, dtype: object

# %%
# Change the data type to datetime format for proper date handling 
C_Date.date = C_Date.date.astype('datetime64[ns]')

# %%
C_Date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    161 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.4 KB

# %%
# Join both DataFrames to merge their data for comprehensive analysis
Today_Rain_Fall = df1.join(C_Date)

# %%
Today_Rain_Fall.columns
# Out:
# Index(['dept', 'dist', 'station', 'value', 'date'], dtype='object')

# %%
# The final cleaned and processed dataset is ready for analysis or further use.
Today_Rain_Fall
# Out:
#         dept        dist                     station  value       date
# 0    Revenue    Ariyalur              Suthamalli dam    5.0 2024-12-30
# 1    Revenue    Ariyalur                    Kuruvadi    4.0 2024-12-30
# 2    Revenue    Ariyalur    Jayankondam taluk office    4.0 2024-12-30
# 3    Revenue    Ariyalur         PWD Office,Sendurai    3.6 2024-12-30
# 4    Revenue    Ariyalur      Taluk Office,Andimadam    3.0 2024-12-30
# ..       ...         ...                         ...    ...        ...
# 155  Revenue  Villupuram         RSCL-3 Avalurpettai    2.0 2024-12-30
# 156  Revenue  Villupuram            SCS MILL Arasoor    2.0 2024-12-30
# 157  Revenue  Villupuram  SCS MILL Thiruvennainallur    2.0 2024-12-30
# 158  Revenue  Villupuram             RSCL-2 Kanjanur    1.0 2024-12-30
# 159  Revenue  Villupuram              RSCL-3 Valathy    1.0 2024-12-30
#
# [160 rows x 5 columns]

# %%
Today_Rain_Fall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dept     160 non-null    object
#  1   dist     160 non-null    object
#  2   station  160 non-null    object
#  3   value    160 non-null    float64
#  4   date     160 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 6.4+ KB

# %% [markdown]
# # Fusing Historical and Updated Rainfall Data for Advanced Analysis

# %%
# Read File
TN_Rain_Fall_History = pd.read_csv(r"C:\Users\Arunprakash Babu\OneDrive\ドキュメント\GitHub\Portfolios\Projects\Pb5_Rainfall data analysis of TN\Total_Rain_Fall_Data.csv", index_col = 0)

# %%
TN_Rain_Fall_History
# Out:
#            dept            dist                      station  value  \
# id
# 0       Revenue    The Nilgiris                       Devala    5.0
# 1       Revenue      Coimbatore       Taluk Office, Pollachi    8.0
# 2       Revenue      Coimbatore       Taluk Office, Pollachi   34.0
# 3       Revenue  Mayiladuthurai  Anaikaranchatram (Kollidam)   13.0
# 4       Revenue  Mayiladuthurai                      Sirkali   12.4
# ...         ...             ...                          ...    ...
# 651039  Revenue      Villupuram          RSCL-3 Avalurpettai    2.0
# 651040  Revenue      Villupuram             SCS MILL Arasoor    2.0
# 651041  Revenue      Villupuram   SCS MILL Thiruvennainallur    2.0
# 651042  Revenue      Villupuram              RSCL-2 Kanjanur    1.0
# 651043  Revenue      Villupuram               RSCL-3 Valathy    1.0
#
#               date
# id
# 0       1990-02-13
# 1       1990-10-17
# 2       1990-10-18
# 3       1990-10-18
# 4       1990-10-18
# ...            ...
# 651039  2024-12-30
# 651040  2024-12-30
# 651041  2024-12-30
# 651042  2024-12-30
# 651043  2024-12-30
#
# [651044 rows x 5 columns]

# %%
TN_Rain_Fall_History.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 651044 entries, 0 to 651043
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   dept     651044 non-null  object
#  1   dist     651044 non-null  object
#  2   station  651044 non-null  object
#  3   value    651044 non-null  float64
#  4   date     651044 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 29.8+ MB

# %% [markdown]
# ## Change datatype of date colum

# %%
TN_Rain_Fall_History.date = pd.to_datetime(TN_Rain_Fall_History.date, dayfirst = True)
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_14532\1025724476.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   TN_Rain_Fall_History.date = pd.to_datetime(TN_Rain_Fall_History.date, dayfirst = True)

# %%
TN_Rain_Fall_History.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 651044 entries, 0 to 651043
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   dept     651044 non-null  object
#  1   dist     651044 non-null  object
#  2   station  651044 non-null  object
#  3   value    651044 non-null  float64
#  4   date     651044 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 29.8+ MB

# %%
Today_Rain_Fall.loc[1]
# Out:
# dept                   Revenue
# dist                  Ariyalur
# station               Kuruvadi
# value                      4.0
# date       2024-12-30 00:00:00
# Name: 1, dtype: object

# %%
TN_Rain_Fall_History.loc[len(TN_Rain_Fall_History)-1][4]
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_14532\1096596789.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   TN_Rain_Fall_History.loc[len(TN_Rain_Fall_History)-1][4]
# Timestamp('2024-12-30 00:00:00')

# %%
Today_Rain_Fall.loc[0][4]
# Out:
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_14532\2699508685.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Today_Rain_Fall.loc[0][4]
# Timestamp('2024-12-30 00:00:00')

# %% [markdown]
# ## Fusing Two DataFrames for Comprehensive Data Processing

# %%
if TN_Rain_Fall_History.loc[len(TN_Rain_Fall_History)-1][4] != Today_Rain_Fall.loc[0][4] :
    Total_Rain_Fall_Data = pd.concat([TN_Rain_Fall_History,Today_Rain_Fall])
    print("Data Added")
else :
    Total_Rain_Fall_Data = TN_Rain_Fall_History
    print("No Change")
# Out:
# No Change
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_14532\673482482.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if TN_Rain_Fall_History.loc[len(TN_Rain_Fall_History)-1][4] != Today_Rain_Fall.loc[0][4] :

# %%
Total_Rain_Fall_Data
# Out:
#            dept            dist                      station  value       date
# id
# 0       Revenue    The Nilgiris                       Devala    5.0 1990-02-13
# 1       Revenue      Coimbatore       Taluk Office, Pollachi    8.0 1990-10-17
# 2       Revenue      Coimbatore       Taluk Office, Pollachi   34.0 1990-10-18
# 3       Revenue  Mayiladuthurai  Anaikaranchatram (Kollidam)   13.0 1990-10-18
# 4       Revenue  Mayiladuthurai                      Sirkali   12.4 1990-10-18
# ...         ...             ...                          ...    ...        ...
# 651039  Revenue      Villupuram          RSCL-3 Avalurpettai    2.0 2024-12-30
# 651040  Revenue      Villupuram             SCS MILL Arasoor    2.0 2024-12-30
# 651041  Revenue      Villupuram   SCS MILL Thiruvennainallur    2.0 2024-12-30
# 651042  Revenue      Villupuram              RSCL-2 Kanjanur    1.0 2024-12-30
# 651043  Revenue      Villupuram               RSCL-3 Valathy    1.0 2024-12-30
#
# [651044 rows x 5 columns]

# %%
# Checking row counts modified
print(len(TN_Rain_Fall_History))
print(len(Today_Rain_Fall))
print(len(TN_Rain_Fall_History)+len(Today_Rain_Fall))
print(len(Total_Rain_Fall_Data.index))
(len(TN_Rain_Fall_History)+len(Today_Rain_Fall)) == len(Total_Rain_Fall_Data.index)
# Out:
# 651044
# 160
# 651204
# 651044
# False

# %%
# Reset Index value
Total_Rain_Fall_Data = Total_Rain_Fall_Data.reset_index(drop = True)

# %%
Total_Rain_Fall_Data.index.name = 'id'

# %%
Total_Rain_Fall_Data
# Out:
#            dept            dist                      station  value       date
# id
# 0       Revenue    The Nilgiris                       Devala    5.0 1990-02-13
# 1       Revenue      Coimbatore       Taluk Office, Pollachi    8.0 1990-10-17
# 2       Revenue      Coimbatore       Taluk Office, Pollachi   34.0 1990-10-18
# 3       Revenue  Mayiladuthurai  Anaikaranchatram (Kollidam)   13.0 1990-10-18
# 4       Revenue  Mayiladuthurai                      Sirkali   12.4 1990-10-18
# ...         ...             ...                          ...    ...        ...
# 651039  Revenue      Villupuram          RSCL-3 Avalurpettai    2.0 2024-12-30
# 651040  Revenue      Villupuram             SCS MILL Arasoor    2.0 2024-12-30
# 651041  Revenue      Villupuram   SCS MILL Thiruvennainallur    2.0 2024-12-30
# 651042  Revenue      Villupuram              RSCL-2 Kanjanur    1.0 2024-12-30
# 651043  Revenue      Villupuram               RSCL-3 Valathy    1.0 2024-12-30
#
# [651044 rows x 5 columns]

# %%
# Export all data
Total_Rain_Fall_Data.to_csv(r"C:\Users\Arunprakash Babu\OneDrive\ドキュメント\GitHub\Portfolios\Projects\Pb5_Rainfall data analysis of TN\Total_Rain_Fall_Data.csv")
